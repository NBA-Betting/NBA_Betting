# %% [markdown]
# # Imports and Global Settings

# %%
import sys
import datetime
import pandas as pd
from sqlalchemy import create_engine

sys.path.append('../')
from ..passkeys import RDS_ENDPOINT, RDS_PASSWORD

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 100

# %% [markdown]
# # Data Inbound

# %%
username = 'postgres'
password = RDS_PASSWORD
endpoint = RDS_ENDPOINT
database = 'nba_betting'
port = '5432'

# %%
connection= create_engine(f'postgresql+psycopg2://{username}:{password}@{endpoint}/{database}').connect()

# %%
current_odds = pd.read_sql_table('dfc_covers_odds', connection)
current_game_results = pd.read_sql_table('dfc_covers_game_results', connection)
historic_odds = pd.read_sql_table('dfh_covers_odds', connection)

# %%
traditional = pd.read_sql_table('traditional', connection)
advanced = pd.read_sql_table('advanced', connection)
four_factors = pd.read_sql_table('four_factors', connection)
misc = pd.read_sql_table('misc', connection)
scoring = pd.read_sql_table('scoring', connection)
opponent = pd.read_sql_table('opponent', connection)
speed_distance = pd.read_sql_table('speed_distance', connection)
shooting = pd.read_sql_table('shooting', connection)
opponent_shooting = pd.read_sql_table('opponent_shooting', connection)
hustle = pd.read_sql_table('hustle', connection)

# %% [markdown]
# # Standardize Dates

# %%
def date_helper(old_date):
    if isinstance(old_date, datetime.datetime): 
        new_date = old_date.strftime('%Y%m%d')
    else:
        new_date = old_date.replace('-', '')
    return pd.to_datetime(new_date)

# %%
traditional['date'] = traditional['date'].apply(date_helper)
advanced['date'] = advanced['date'].apply(date_helper)
four_factors['date'] = four_factors['date'].apply(date_helper)
misc['date'] = misc['date'].apply(date_helper)
scoring['date'] = scoring['date'].apply(date_helper)
opponent['date'] = opponent['date'].apply(date_helper)
speed_distance['date'] = speed_distance['date'].apply(date_helper)
shooting['date'] = shooting['date'].apply(date_helper)
opponent_shooting['date'] = opponent_shooting['date'].apply(date_helper)
hustle['date'] = hustle['date'].apply(date_helper)

# %%
current_odds['date'] = pd.to_datetime(current_odds['date'])
current_game_results['date'] = pd.to_datetime(current_game_results['date'])
historic_odds['date'] = pd.to_datetime(historic_odds['date'])

# %% [markdown]
# # Standardize Team Names

# %%
    team_full_name_map = {
        "Washington Wizards": "WAS",
        "Brooklyn Nets": "BKN",
        "Chicago Bulls": "CHI",
        "Miami Heat": "MIA",
        "Cleveland Cavaliers": "CLE",
        "Philadelphia 76ers": "PHI",
        "New York Knicks": "NYK",
        "Charlotte Hornets": "CHA",
        "Boston Celtics": "BOS",
        "Toronto Raptors": "TOR",
        "Milwaukee Bucks": "MIL",
        "Atlanta Hawks": "ATL",
        "Indiana Pacers": "IND",
        "Detroit Pistons": "DET",
        "Orlando Magic": "ORL",
        "Golden State Warriors": "GSW",
        "Phoenix Suns": "PHX",
        "Dallas Mavericks": "DAL",
        "Denver Nuggets": "DEN",
        "Los Angeles Clippers": "LAC",
        "LA Clippers": "LAC",
        "Utah Jazz": "UTA",
        "Los Angeles Lakers": "LAL",
        "Memphis Grizzlies": "MEM",
        "Portland Trail Blazers": "POR",
        "Sacramento Kings": "SAC",
        "Oklahoma City Thunder": "OKC",
        "Minnesota Timberwolves": "MIN",
        "San Antonio Spurs": "SAS",
        "New Orleans Pelicans": "NOP",
        "Houston Rockets": "HOU",
        "Charlotte Bobcats": "CHA",
        "New Orleans Hornets": "NOP",
        "New Jersey Nets": "BKN",
        "Seattle SuperSonics": "OKC",
        "New Orleans/Oklahoma City Hornets": "NOP",
    }

    team_abrv_map = {
        "BK": "BKN",
        "BKN": "BKN",
        "BOS": "BOS",
        "MIL": "MIL",
        "ATL": "ATL",
        "CHA": "CHA",
        "CHO": "CHA",
        "CHI": "CHI",
        "CLE": "CLE",
        "DAL": "DAL",
        "DEN": "DEN",
        "DET": "DET",
        "GS": "GSW",
        "GSW": "GSW",
        "HOU": "HOU",
        "IND": "IND",
        "LAC": "LAC",
        "LAL": "LAL",
        "MEM": "MEM",
        "MIA": "MIA",
        "MIN": "MIN",
        "NO": "NOP",
        "NOP": "NOP",
        "NY": "NYK",
        "NYK": "NYK",
        "OKC": "OKC",
        "ORL": "ORL",
        "PHI": "PHI",
        "PHO": "PHX",
        "PHX": "PHX",
        "POR": "POR",
        "SA": "SAS",
        "SAS": "SAS",
        "SAC": "SAC",
        "TOR": "TOR",
        "UTA": "UTA",
        "WAS": "WAS",
    }

    team_short_name_map = {
        "Nets": "BKN",
        "Celtics": "BOS",
        "Bucks": "MIL",
        "Hawks": "ATL",
        "Hornets": "CHA",
        "Bulls": "CHI",
        "Cavaliers": "CLE",
        "Mavericks": "DAL",
        "Nuggets": "DEN",
        "Pistons": "DET",
        "Warriors": "GSW",
        "Rockets": "HOU",
        "Pacers": "IND",
        "Clippers": "LAC",
        "Lakers": "LAL",
        "Grizzlies": "MEM",
        "Heat": "MIA",
        "Timberwolves": "MIN",
        "Pelicans": "NOP",
        "Knicks": "NYK",
        "Thunder": "OKC",
        "Magic": "ORL",
        "76ers": "PHI",
        "Suns": "PHX",
        "Trail Blazers": "POR",
        "Spurs": "SAS",
        "Kings": "SAC",
        "Raptors": "TOR",
        "Jazz": "UTA",
        "Wizards": "WAS",
    }

    teams = dict(
        team_full_name_map.items()
        | team_abrv_map.items()
        | team_short_name_map.items()
    )

# %%
traditional['team'] = traditional['team'].map(teams)
advanced['team'] = advanced['team'].map(teams)
four_factors['team'] = four_factors['team'].map(teams)
misc['team'] = misc['team'].map(teams)
scoring['team'] = scoring['team'].map(teams)
opponent['team'] = opponent['team'].map(teams)
speed_distance['team'] = speed_distance['team'].map(teams)
shooting['team'] = shooting['team'].map(teams)
opponent_shooting['team'] = opponent_shooting['team'].map(teams)
hustle['team'] = hustle['team'].map(teams)

# %%
current_odds['team'] = current_odds['home_team_short_name'].map(teams)

# %%
current_odds['opponent'] = current_odds['away_team_short_name'].map(teams)

# %%
current_game_results['team'] = current_game_results['home_team'].map(teams)

# %%
current_game_results['opponent'] = current_game_results['away_team'].map(teams)

# %% [markdown]
# # Remove Duplicates and Empty Rows

# %%
traditional = traditional.dropna(thresh=3)
traditional = traditional.drop_duplicates(subset=['date', 'team'], keep='last')
advanced = advanced.dropna(thresh=3)
advanced = advanced.drop_duplicates(subset=['date', 'team'], keep='last')
four_factors = four_factors.dropna(thresh=3)
four_factors = four_factors.drop_duplicates(subset=['date', 'team'], keep='last')
misc = misc.dropna(thresh=3)
misc = misc.drop_duplicates(subset=['date', 'team'], keep='last')
scoring = scoring.dropna(thresh=3)
scoring = scoring.drop_duplicates(subset=['date', 'team'], keep='last')
opponent = opponent.dropna(thresh=3)
opponent = opponent.drop_duplicates(subset=['date', 'team'], keep='last')
speed_distance = speed_distance.dropna(thresh=3)
speed_distance = speed_distance.drop_duplicates(subset=['date', 'team'], keep='last')
shooting = shooting.dropna(thresh=3)
shooting = shooting.drop_duplicates(subset=['date', 'team'], keep='last')
opponent_shooting = opponent_shooting.dropna(thresh=3)
opponent_shooting = opponent_shooting.drop_duplicates(subset=['date', 'team'], keep='last')
hustle = hustle.dropna(thresh=3)
hustle = hustle.drop_duplicates(subset=['date', 'team'], keep='last')

# %%
current_game_results = current_game_results.drop_duplicates()

# %% [markdown]
# # Combine Data

# %%
historic_odds['pred_date'] = historic_odds['date'] - pd.DateOffset(1)

# %%
current_odds['pred_date'] = current_odds['date'] - pd.DateOffset(1)

# %%
historic_df = historic_odds.copy()

# %%
for stat_group in [traditional, advanced, four_factors, misc, scoring, opponent,
                   speed_distance, shooting, opponent_shooting, hustle]:
    historic_df = historic_df.merge(stat_group,
                                   how='left',
                                   left_on=['team', 'pred_date'],
                                   right_on=['team', 'date'],
                                   suffixes=(None, '_nba'),
                                   validate='1:m')
    historic_df = historic_df.drop(columns=['date_nba', 'date_opp', 'team_opp'], errors='ignore')
    historic_df = historic_df.merge(stat_group,
                                    how='left',
                                    left_on=['opponent', 'pred_date'],
                                    right_on=['team', 'date'],
                                    suffixes=(None, '_opp'),
                                    validate='1:m')
    historic_df = historic_df.drop(columns=['date_nba', 'date_opp', 'team_opp'], errors='ignore')

# %%
side_df = current_odds.merge(current_game_results,
                                   how='left',
                                   left_on=['team', 'date'],
                                   right_on=['team', 'date'],
                                   suffixes=(None, '_gr'),
                                   validate='1:1')

# %%
for stat_group in [traditional, advanced, four_factors, misc, scoring,
                   opponent, speed_distance, shooting, opponent_shooting, hustle]:
    side_df = side_df.merge(stat_group,
                                   how='left',
                                   left_on=['team', 'pred_date'],
                                   right_on=['team', 'date'],
                                   suffixes=(None, '_nba'),
                                   validate='1:m')
    side_df = side_df.drop(columns=['date_nba', 'date_opp', 'team_opp'], errors='ignore')
    side_df = side_df.merge(stat_group,
                                   how='left',
                                   left_on=['opponent', 'pred_date'],
                                   right_on=['team', 'date'],
                                   suffixes=(None, '_opp'),
                                   validate='1:m')
    side_df = side_df.drop(columns=['date_nba', 'date_opp', 'team_opp'], errors='ignore')

# %% [markdown]
# ### Select Dates - Side Df

# %%
side_df = side_df[side_df['date'].between('2022-05-12', '2022-05-21', inclusive=False)]

# %% [markdown]
# # Concat Dataframes

# %%
side_df = side_df.drop(columns=['time', 'home_team_full_name',
                                'away_team_full_name', 'open_line_away'])

# %%
side_df = side_df.rename(columns={'id_num': 'id',
                                    'home_score': 'score',
                                    'away_score': 'opponent_score',
                                    'link': 'game_url',
                                    'open_line_home': 'spread'})

# %%
side_df['result'] = side_df.apply(lambda x: 'W' if x['score'] > x['opponent_score'] else 'L', axis=1)

# %%
side_df['spread_result'] = side_df.apply(lambda x: 'W' if (x['score'] - x['opponent_score']) > -x['spread'] else 'L', axis=1)

# %%
full_dataset = pd.concat((side_df, historic_df), ignore_index=True)

# %% [markdown]
# # Create Unique Record ID

# %%
full_dataset['game_id'] = full_dataset['date'].apply(lambda x: x.strftime('%Y%m%d')) + full_dataset['team'] + full_dataset['opponent']

# %% [markdown]
# # Cleanup

# %% [markdown]
# ## Remove Excess Columns

# %%
columns_to_drop = ['id', 'home_team_short_name', 'away_team_short_name', 'opponent_gr',
                   'home_team', 'away_team']

# %%
full_dataset = full_dataset.drop(columns=columns_to_drop)

# %% [markdown]
# ## Rename Columns

# %%
column_rename_dict = {'date': 'game_date', 'team': 'home_team', 'opponent': 'away_team',
                      'score': 'home_score', 'opponent_score': 'away_score', 'result': 'home_result',
                      'game_url': 'covers_game_url', 'spread': 'home_spread',
                      'spread_result': 'home_spread_result',
                      "fanduel_line_home": "fd_line_home",
                      "fanduel_line_price_home": "fd_line_price_home",
                      "fanduel_line_away": "fd_line_away",
                      "fanduel_line_price_away": "fd_line_price_away",
                      "draftkings_line_home": "dk_line_home",
                      "draftkings_line_price_home": "dk_line_price_home",
                      "draftkings_line_away": "dk_line_away",
                      "draftkings_line_price_away": "dk_line_price_away",
                      "covers_home_consenses": "covers_consenses_home",
                      "covers_away_consenses": "covers_consenses_away"}

# %%
full_dataset = full_dataset.rename(columns=column_rename_dict)

# %% [markdown]
# ## Reorder Columns

# %%
main_features = ['game_id',
                 'game_date',
                 'home_team',
                 'away_team',
                 'home_score',
                 'away_score',
                 'home_result',
                 'league_year',
                 'pred_date',
                 'home_spread',
                 'home_spread_result',
                 'covers_game_url',
                 "fd_line_home",
                 "fd_line_price_home",
                 "fd_line_away",
                 "fd_line_price_away",
                 "dk_line_home",
                 "dk_line_price_home",
                 "dk_line_away",
                 "dk_line_price_away",
                 "covers_consenses_home",
                 "covers_consenses_away"]

all_features = main_features + [i for i in list(full_dataset) if i not in main_features]

# %%
full_dataset = full_dataset[all_features]

# %% [markdown]
# # Select Dates

# %%
# Ignoring first 5 days due to missing data
date_mask_2022 = (
        full_dataset['pred_date'] >= pd.to_datetime("October 24, 2021")) & (
            full_dataset['game_date'] <= pd.to_datetime("April 10, 2022"))

date_mask_2021 = (
        full_dataset['pred_date'] >= pd.to_datetime("December 27, 2020")) & (
            full_dataset['game_date'] <= pd.to_datetime("May 16, 2021"))

date_mask_2020 = (
        full_dataset['pred_date'] >= pd.to_datetime("October 27, 2019")) & (
            full_dataset['game_date'] <= pd.to_datetime("August 14, 2020"))

date_mask_2019 = (
        full_dataset['pred_date'] >= pd.to_datetime("October 21, 2018")) & (
            full_dataset['game_date'] <= pd.to_datetime("April 10, 2019"))

date_mask_2018 = (
        full_dataset['pred_date'] >= pd.to_datetime("October 22, 2017")) & (
            full_dataset['game_date'] <= pd.to_datetime("April 11, 2018"))

date_mask_2017 = (
        full_dataset['pred_date'] >= pd.to_datetime("October 29, 2016")) & (
            full_dataset['game_date'] <= pd.to_datetime("April 12, 2017"))

date_mask_2016 = (
        full_dataset['pred_date'] >= pd.to_datetime("November 1, 2015")) & (
            full_dataset['game_date'] <= pd.to_datetime("April 13, 2016"))

date_mask_2015 = (
        full_dataset['pred_date'] >= pd.to_datetime("November 2, 2014")) & (
            full_dataset['game_date'] <= pd.to_datetime("April 15, 2015"))

# %%
full_dataset = full_dataset[date_mask_2022 | date_mask_2021 | date_mask_2020 | date_mask_2019 | date_mask_2018 | date_mask_2017 | date_mask_2016 | date_mask_2015]

# %% [markdown]
# # Review Data

# %%
full_dataset.isna().sum()
# Out:
# game_id                           0
# game_date                         0
# home_team                         0
# away_team                         0
# home_score                        0
#                                ...
# contested_3pt_vla_opp          2130
# contested_3pt_vla_std_opp      2130
# contested_shots_rank_opp       2130
# contested_shots_vla_opp        2130
# contested_shots_vla_std_opp    2130
# Length: 1230, dtype: int64

# %%
full_dataset.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9200 entries, 11 to 20042
# Data columns (total 1230 columns):
#  #     Column                              Non-Null Count  Dtype
# ---    ------                              --------------  -----
#  0     game_id                             9200 non-null   object
#  1     game_date                           9200 non-null   datetime64[ns]
#  2     home_team                           9200 non-null   object
#  3     away_team                           9200 non-null   object
#  4     home_score                          9200 non-null   float64
#  5     away_score                          9200 non-null   float64
#  6     home_result                         9200 non-null   object
#  7     league_year                         9200 non-null   object
#  8     pred_date                           9200 non-null   datetime64[ns]
#  9     home_spread                         9200 non-null   float64
#  10    home_spread_result                  9200 non-null   object
#  11    covers_game_url                     9200 non-null   object
#  12    fd_line_home                        0 non-null      float64
#  13    fd_line_price_home                  0 non-null      float64
#  14    fd_line_away                        0 non-null      float64
#  15    fd_line_price_away                  0 non-null      float64
#  16    dk_line_home                        0 non-null      float64
#  17    dk_line_price_home                  0 non-null      float64
#  18    dk_line_away                        0 non-null      float64
#  19    dk_line_price_away                  0 non-null      float64
#  20    covers_consenses_home               0 non-null      float64
#  21    covers_consenses_away               0 non-null      float64
#  22    gp                                  9172 non-null   float64
#  23    win                                 9172 non-null   float64
#  24    loss                                9172 non-null   float64
#  25    w_pct                               9172 non-null   float64
#  26    mins                                9172 non-null   float64
#  27    pts                                 9172 non-null   float64
#  28    fgm                                 9172 non-null   float64
#  29    fga                                 9172 non-null   float64
#  30    fg_pct                              9172 non-null   float64
#  31    fg3m                                9172 non-null   float64
#  32    fg3a                                9172 non-null   float64
#  33    fg3_pct                             9172 non-null   float64
#  34    ftm                                 9172 non-null   float64
#  35    fta                                 9172 non-null   float64
#  36    ft_pct                              9172 non-null   float64
#  37    oreb                                9172 non-null   float64
#  38    dreb                                9172 non-null   float64
#  39    reb                                 9172 non-null   float64
#  40    ast                                 9172 non-null   float64
#  41    tov                                 9172 non-null   float64
#  42    stl                                 9172 non-null   float64
#  43    blk                                 9172 non-null   float64
#  44    blka                                9172 non-null   float64
#  45    pf                                  9172 non-null   float64
#  46    pfd                                 9172 non-null   float64
#  47    p_m                                 9172 non-null   float64
#  48    gp_rank                             9172 non-null   float64
#  49    gp_vla                              9172 non-null   float64
#  50    gp_vla_std                          9142 non-null   float64
#  51    win_rank                            9172 non-null   float64
#  52    win_vla                             9172 non-null   float64
#  53    win_vla_std                         9172 non-null   float64
#  54    loss_rank                           9172 non-null   float64
#  55    loss_vla                            9172 non-null   float64
#  56    loss_vla_std                        9172 non-null   float64
#  57    w_pct_rank                          9172 non-null   float64
#  58    w_pct_vla                           9172 non-null   float64
#  59    w_pct_vla_std                       9172 non-null   float64
#  60    mins_rank                           9172 non-null   float64
#  61    mins_vla                            9172 non-null   float64
#  62    mins_vla_std                        9147 non-null   float64
#  63    pts_rank                            9172 non-null   float64
#  64    pts_vla                             9172 non-null   float64
#  65    pts_vla_std                         9172 non-null   float64
#  66    fgm_rank                            9172 non-null   float64
#  67    fgm_vla                             9172 non-null   float64
#  68    fgm_vla_std                         9172 non-null   float64
#  69    fga_rank                            9172 non-null   float64
#  70    fga_vla                             9172 non-null   float64
#  71    fga_vla_std                         9172 non-null   float64
#  72    fg_pct_rank                         9172 non-null   float64
#  73    fg_pct_vla                          9172 non-null   float64
#  74    fg_pct_vla_std                      9172 non-null   float64
#  75    fg3m_rank                           9172 non-null   float64
#  76    fg3m_vla                            9172 non-null   float64
#  77    fg3m_vla_std                        9172 non-null   float64
#  78    fg3a_rank                           9172 non-null   float64
#  79    fg3a_vla                            9172 non-null   float64
#  80    fg3a_vla_std                        9172 non-null   float64
#  81    fg3_pct_rank                        9172 non-null   float64
#  82    fg3_pct_vla                         9172 non-null   float64
#  83    fg3_pct_vla_std                     9172 non-null   float64
#  84    ftm_rank                            9172 non-null   float64
#  85    ftm_vla                             9172 non-null   float64
#  86    ftm_vla_std                         9172 non-null   float64
#  87    fta_rank                            9172 non-null   float64
#  88    fta_vla                             9172 non-null   float64
#  89    fta_vla_std                         9172 non-null   float64
#  90    ft_pct_rank                         9172 non-null   float64
#  91    ft_pct_vla                          9172 non-null   float64
#  92    ft_pct_vla_std                      9172 non-null   float64
#  93    oreb_rank                           9172 non-null   float64
#  94    oreb_vla                            9172 non-null   float64
#  95    oreb_vla_std                        9172 non-null   float64
#  96    dreb_rank                           9172 non-null   float64
#  97    dreb_vla                            9172 non-null   float64
#  98    dreb_vla_std                        9172 non-null   float64
#  99    reb_rank                            9172 non-null   float64
#  100   reb_vla                             9172 non-null   float64
#  101   reb_vla_std                         9172 non-null   float64
#  102   ast_rank                            9172 non-null   float64
#  103   ast_vla                             9172 non-null   float64
#  104   ast_vla_std                         9172 non-null   float64
#  105   tov_rank                            9172 non-null   float64
#  106   tov_vla                             9172 non-null   float64
#  107   tov_vla_std                         9172 non-null   float64
#  108   stl_rank                            9172 non-null   float64
#  109   stl_vla                             9172 non-null   float64
#  110   stl_vla_std                         9172 non-null   float64
#  111   blk_rank                            9172 non-null   float64
#  112   blk_vla                             9172 non-null   float64
#  113   blk_vla_std                         9172 non-null   float64
#  114   blka_rank                           9172 non-null   float64
#  115   blka_vla                            9172 non-null   float64
#  116   blka_vla_std                        9172 non-null   float64
#  117   pf_rank                             9172 non-null   float64
#  118   pf_vla                              9172 non-null   float64
#  119   pf_vla_std                          9172 non-null   float64
#  120   pfd_rank                            9172 non-null   float64
#  121   pfd_vla                             9172 non-null   float64
#  122   pfd_vla_std                         9172 non-null   float64
#  123   p_m_rank                            9172 non-null   float64
#  124   p_m_vla                             9172 non-null   float64
#  125   p_m_vla_std                         9172 non-null   float64
#  126   gp_opp                              9172 non-null   float64
#  127   win_opp                             9172 non-null   float64
#  128   loss_opp                            9172 non-null   float64
#  129   w_pct_opp                           9172 non-null   float64
#  130   mins_opp                            9172 non-null   float64
#  131   pts_opp                             9172 non-null   float64
#  132   fgm_opp                             9172 non-null   float64
#  133   fga_opp                             9172 non-null   float64
#  134   fg_pct_opp                          9172 non-null   float64
#  135   fg3m_opp                            9172 non-null   float64
#  136   fg3a_opp                            9172 non-null   float64
#  137   fg3_pct_opp                         9172 non-null   float64
#  138   ftm_opp                             9172 non-null   float64
#  139   fta_opp                             9172 non-null   float64
#  140   ft_pct_opp                          9172 non-null   float64
#  141   oreb_opp                            9172 non-null   float64
#  142   dreb_opp                            9172 non-null   float64
#  143   reb_opp                             9172 non-null   float64
#  144   ast_opp                             9172 non-null   float64
#  145   tov_opp                             9172 non-null   float64
#  146   stl_opp                             9172 non-null   float64
#  147   blk_opp                             9172 non-null   float64
#  148   blka_opp                            9172 non-null   float64
#  149   pf_opp                              9172 non-null   float64
#  150   pfd_opp                             9172 non-null   float64
#  151   p_m_opp                             9172 non-null   float64
#  152   gp_rank_opp                         9172 non-null   float64
#  153   gp_vla_opp                          9172 non-null   float64
#  154   gp_vla_std_opp                      9142 non-null   float64
#  155   win_rank_opp                        9172 non-null   float64
#  156   win_vla_opp                         9172 non-null   float64
#  157   win_vla_std_opp                     9172 non-null   float64
#  158   loss_rank_opp                       9172 non-null   float64
#  159   loss_vla_opp                        9172 non-null   float64
#  160   loss_vla_std_opp                    9172 non-null   float64
#  161   w_pct_rank_opp                      9172 non-null   float64
#  162   w_pct_vla_opp                       9172 non-null   float64
#  163   w_pct_vla_std_opp                   9172 non-null   float64
#  164   mins_rank_opp                       9172 non-null   float64
#  165   mins_vla_opp                        9172 non-null   float64
#  166   mins_vla_std_opp                    9147 non-null   float64
#  167   pts_rank_opp                        9172 non-null   float64
#  168   pts_vla_opp                         9172 non-null   float64
#  169   pts_vla_std_opp                     9172 non-null   float64
#  170   fgm_rank_opp                        9172 non-null   float64
#  171   fgm_vla_opp                         9172 non-null   float64
#  172   fgm_vla_std_opp                     9172 non-null   float64
#  173   fga_rank_opp                        9172 non-null   float64
#  174   fga_vla_opp                         9172 non-null   float64
#  175   fga_vla_std_opp                     9172 non-null   float64
#  176   fg_pct_rank_opp                     9172 non-null   float64
#  177   fg_pct_vla_opp                      9172 non-null   float64
#  178   fg_pct_vla_std_opp                  9172 non-null   float64
#  179   fg3m_rank_opp                       9172 non-null   float64
#  180   fg3m_vla_opp                        9172 non-null   float64
#  181   fg3m_vla_std_opp                    9172 non-null   float64
#  182   fg3a_rank_opp                       9172 non-null   float64
#  183   fg3a_vla_opp                        9172 non-null   float64
#  184   fg3a_vla_std_opp                    9172 non-null   float64
#  185   fg3_pct_rank_opp                    9172 non-null   float64
#  186   fg3_pct_vla_opp                     9172 non-null   float64
#  187   fg3_pct_vla_std_opp                 9172 non-null   float64
#  188   ftm_rank_opp                        9172 non-null   float64
#  189   ftm_vla_opp                         9172 non-null   float64
#  190   ftm_vla_std_opp                     9172 non-null   float64
#  191   fta_rank_opp                        9172 non-null   float64
#  192   fta_vla_opp                         9172 non-null   float64
#  193   fta_vla_std_opp                     9172 non-null   float64
#  194   ft_pct_rank_opp                     9172 non-null   float64
#  195   ft_pct_vla_opp                      9172 non-null   float64
#  196   ft_pct_vla_std_opp                  9172 non-null   float64
#  197   oreb_rank_opp                       9172 non-null   float64
#  198   oreb_vla_opp                        9172 non-null   float64
#  199   oreb_vla_std_opp                    9172 non-null   float64
#  200   dreb_rank_opp                       9172 non-null   float64
#  201   dreb_vla_opp                        9172 non-null   float64
#  202   dreb_vla_std_opp                    9172 non-null   float64
#  203   reb_rank_opp                        9172 non-null   float64
#  204   reb_vla_opp                         9172 non-null   float64
#  205   reb_vla_std_opp                     9172 non-null   float64
#  206   ast_rank_opp                        9172 non-null   float64
#  207   ast_vla_opp                         9172 non-null   float64
#  208   ast_vla_std_opp                     9172 non-null   float64
#  209   tov_rank_opp                        9172 non-null   float64
#  210   tov_vla_opp                         9172 non-null   float64
#  211   tov_vla_std_opp                     9172 non-null   float64
#  212   stl_rank_opp                        9172 non-null   float64
#  213   stl_vla_opp                         9172 non-null   float64
#  214   stl_vla_std_opp                     9172 non-null   float64
#  215   blk_rank_opp                        9172 non-null   float64
#  216   blk_vla_opp                         9172 non-null   float64
#  217   blk_vla_std_opp                     9172 non-null   float64
#  218   blka_rank_opp                       9172 non-null   float64
#  219   blka_vla_opp                        9172 non-null   float64
#  220   blka_vla_std_opp                    9172 non-null   float64
#  221   pf_rank_opp                         9172 non-null   float64
#  222   pf_vla_opp                          9172 non-null   float64
#  223   pf_vla_std_opp                      9172 non-null   float64
#  224   pfd_rank_opp                        9172 non-null   float64
#  225   pfd_vla_opp                         9172 non-null   float64
#  226   pfd_vla_std_opp                     9172 non-null   float64
#  227   p_m_rank_opp                        9172 non-null   float64
#  228   p_m_vla_opp                         9172 non-null   float64
#  229   p_m_vla_std_opp                     9172 non-null   float64
#  230   offrtg                              9168 non-null   float64
#  231   defrtg                              9168 non-null   float64
#  232   netrtg                              9168 non-null   float64
#  233   ast_pct                             9168 non-null   float64
#  234   ast_v_tov                           9168 non-null   float64
#  235   ast_ratio                           9168 non-null   float64
#  236   oreb_pct                            9168 non-null   float64
#  237   dreb_pct                            9168 non-null   float64
#  238   reb_pct                             9168 non-null   float64
#  239   tov_pct                             9168 non-null   float64
#  240   efg_pct                             9168 non-null   float64
#  241   ts_pct                              9168 non-null   float64
#  242   pace                                9168 non-null   float64
#  243   pie                                 9168 non-null   float64
#  244   poss                                9168 non-null   float64
#  245   offrtg_rank                         9168 non-null   float64
#  246   offrtg_vla                          9168 non-null   float64
#  247   offrtg_vla_std                      9168 non-null   float64
#  248   defrtg_rank                         9168 non-null   float64
#  249   defrtg_vla                          9168 non-null   float64
#  250   defrtg_vla_std                      9168 non-null   float64
#  251   netrtg_rank                         9168 non-null   float64
#  252   netrtg_vla                          9168 non-null   float64
#  253   netrtg_vla_std                      9168 non-null   float64
#  254   ast_pct_rank                        9168 non-null   float64
#  255   ast_pct_vla                         9168 non-null   float64
#  256   ast_pct_vla_std                     9168 non-null   float64
#  257   ast_v_tov_rank                      9168 non-null   float64
#  258   ast_v_tov_vla                       9168 non-null   float64
#  259   ast_v_tov_vla_std                   9168 non-null   float64
#  260   ast_ratio_rank                      9168 non-null   float64
#  261   ast_ratio_vla                       9168 non-null   float64
#  262   ast_ratio_vla_std                   9168 non-null   float64
#  263   oreb_pct_rank                       9168 non-null   float64
#  264   oreb_pct_vla                        9168 non-null   float64
#  265   oreb_pct_vla_std                    9168 non-null   float64
#  266   dreb_pct_rank                       9168 non-null   float64
#  267   dreb_pct_vla                        9168 non-null   float64
#  268   dreb_pct_vla_std                    9168 non-null   float64
#  269   reb_pct_rank                        9168 non-null   float64
#  270   reb_pct_vla                         9168 non-null   float64
#  271   reb_pct_vla_std                     9168 non-null   float64
#  272   tov_pct_rank                        9168 non-null   float64
#  273   tov_pct_vla                         9168 non-null   float64
#  274   tov_pct_vla_std                     9168 non-null   float64
#  275   efg_pct_rank                        9168 non-null   float64
#  276   efg_pct_vla                         9168 non-null   float64
#  277   efg_pct_vla_std                     9168 non-null   float64
#  278   ts_pct_rank                         9168 non-null   float64
#  279   ts_pct_vla                          9168 non-null   float64
#  280   ts_pct_vla_std                      9168 non-null   float64
#  281   pace_rank                           9168 non-null   float64
#  282   pace_vla                            9168 non-null   float64
#  283   pace_vla_std                        9168 non-null   float64
#  284   pie_rank                            9168 non-null   float64
#  285   pie_vla                             9168 non-null   float64
#  286   pie_vla_std                         9168 non-null   float64
#  287   poss_rank                           9168 non-null   float64
#  288   poss_vla                            9168 non-null   float64
#  289   poss_vla_std                        9168 non-null   float64
#  290   offrtg_opp                          9167 non-null   float64
#  291   defrtg_opp                          9167 non-null   float64
#  292   netrtg_opp                          9167 non-null   float64
#  293   ast_pct_opp                         9167 non-null   float64
#  294   ast_v_tov_opp                       9167 non-null   float64
#  295   ast_ratio_opp                       9167 non-null   float64
#  296   oreb_pct_opp                        9167 non-null   float64
#  297   dreb_pct_opp                        9167 non-null   float64
#  298   reb_pct_opp                         9167 non-null   float64
#  299   tov_pct_opp                         9167 non-null   float64
#  300   efg_pct_opp                         9167 non-null   float64
#  301   ts_pct_opp                          9167 non-null   float64
#  302   pace_opp                            9167 non-null   float64
#  303   pie_opp                             9167 non-null   float64
#  304   poss_opp                            9167 non-null   float64
#  305   offrtg_rank_opp                     9167 non-null   float64
#  306   offrtg_vla_opp                      9167 non-null   float64
#  307   offrtg_vla_std_opp                  9167 non-null   float64
#  308   defrtg_rank_opp                     9167 non-null   float64
#  309   defrtg_vla_opp                      9167 non-null   float64
#  310   defrtg_vla_std_opp                  9167 non-null   float64
#  311   netrtg_rank_opp                     9167 non-null   float64
#  312   netrtg_vla_opp                      9167 non-null   float64
#  313   netrtg_vla_std_opp                  9167 non-null   float64
#  314   ast_pct_rank_opp                    9167 non-null   float64
#  315   ast_pct_vla_opp                     9167 non-null   float64
#  316   ast_pct_vla_std_opp                 9167 non-null   float64
#  317   ast_v_tov_rank_opp                  9167 non-null   float64
#  318   ast_v_tov_vla_opp                   9167 non-null   float64
#  319   ast_v_tov_vla_std_opp               9167 non-null   float64
#  320   ast_ratio_rank_opp                  9167 non-null   float64
#  321   ast_ratio_vla_opp                   9167 non-null   float64
#  322   ast_ratio_vla_std_opp               9167 non-null   float64
#  323   oreb_pct_rank_opp                   9167 non-null   float64
#  324   oreb_pct_vla_opp                    9167 non-null   float64
#  325   oreb_pct_vla_std_opp                9167 non-null   float64
#  326   dreb_pct_rank_opp                   9167 non-null   float64
#  327   dreb_pct_vla_opp                    9167 non-null   float64
#  328   dreb_pct_vla_std_opp                9167 non-null   float64
#  329   reb_pct_rank_opp                    9167 non-null   float64
#  330   reb_pct_vla_opp                     9167 non-null   float64
#  331   reb_pct_vla_std_opp                 9167 non-null   float64
#  332   tov_pct_rank_opp                    9167 non-null   float64
#  333   tov_pct_vla_opp                     9167 non-null   float64
#  334   tov_pct_vla_std_opp                 9167 non-null   float64
#  335   efg_pct_rank_opp                    9167 non-null   float64
#  336   efg_pct_vla_opp                     9167 non-null   float64
#  337   efg_pct_vla_std_opp                 9167 non-null   float64
#  338   ts_pct_rank_opp                     9167 non-null   float64
#  339   ts_pct_vla_opp                      9167 non-null   float64
#  340   ts_pct_vla_std_opp                  9167 non-null   float64
#  341   pace_rank_opp                       9167 non-null   float64
#  342   pace_vla_opp                        9167 non-null   float64
#  343   pace_vla_std_opp                    9167 non-null   float64
#  344   pie_rank_opp                        9167 non-null   float64
#  345   pie_vla_opp                         9167 non-null   float64
#  346   pie_vla_std_opp                     9167 non-null   float64
#  347   poss_rank_opp                       9167 non-null   float64
#  348   poss_vla_opp                        9167 non-null   float64
#  349   poss_vla_std_opp                    9167 non-null   float64
#  350   fta_rate                            9200 non-null   float64
#  351   opp_efg_pct                         9200 non-null   float64
#  352   opp_fta_rate                        9200 non-null   float64
#  353   opp_tov_pct                         9200 non-null   float64
#  354   opp_oreb_pct                        9200 non-null   float64
#  355   fta_rate_rank                       9200 non-null   float64
#  356   fta_rate_vla                        9200 non-null   float64
#  357   fta_rate_vla_std                    9200 non-null   float64
#  358   opp_efg_pct_rank                    9200 non-null   float64
#  359   opp_efg_pct_vla                     9200 non-null   float64
#  360   opp_efg_pct_vla_std                 9200 non-null   float64
#  361   opp_fta_rate_rank                   9200 non-null   float64
#  362   opp_fta_rate_vla                    9200 non-null   float64
#  363   opp_fta_rate_vla_std                9200 non-null   float64
#  364   opp_tov_pct_rank                    9200 non-null   float64
#  365   opp_tov_pct_vla                     9200 non-null   float64
#  366   opp_tov_pct_vla_std                 9200 non-null   float64
#  367   opp_oreb_pct_rank                   9200 non-null   float64
#  368   opp_oreb_pct_vla                    9200 non-null   float64
#  369   opp_oreb_pct_vla_std                9200 non-null   float64
#  370   fta_rate_opp                        9200 non-null   float64
#  371   opp_efg_pct_opp                     9200 non-null   float64
#  372   opp_fta_rate_opp                    9200 non-null   float64
#  373   opp_tov_pct_opp                     9200 non-null   float64
#  374   opp_oreb_pct_opp                    9200 non-null   float64
#  375   fta_rate_rank_opp                   9200 non-null   float64
#  376   fta_rate_vla_opp                    9200 non-null   float64
#  377   fta_rate_vla_std_opp                9200 non-null   float64
#  378   opp_efg_pct_rank_opp                9200 non-null   float64
#  379   opp_efg_pct_vla_opp                 9200 non-null   float64
#  380   opp_efg_pct_vla_std_opp             9200 non-null   float64
#  381   opp_fta_rate_rank_opp               9200 non-null   float64
#  382   opp_fta_rate_vla_opp                9200 non-null   float64
#  383   opp_fta_rate_vla_std_opp            9200 non-null   float64
#  384   opp_tov_pct_rank_opp                9200 non-null   float64
#  385   opp_tov_pct_vla_opp                 9200 non-null   float64
#  386   opp_tov_pct_vla_std_opp             9200 non-null   float64
#  387   opp_oreb_pct_rank_opp               9200 non-null   float64
#  388   opp_oreb_pct_vla_opp                9200 non-null   float64
#  389   opp_oreb_pct_vla_std_opp            9200 non-null   float64
#  390   pts_off_tov                         9112 non-null   float64
#  391   second_pts                          9112 non-null   float64
#  392   fbps                                9112 non-null   float64
#  393   pitp                                9112 non-null   float64
#  394   opp_pts_off_tov                     9112 non-null   float64
#  395   opp_second_pts                      9112 non-null   float64
#  396   opp_fbps                            9112 non-null   float64
#  397   opp_pitp                            9112 non-null   float64
#  398   pts_off_tov_rank                    9112 non-null   float64
#  399   pts_off_tov_vla                     9112 non-null   float64
#  400   pts_off_tov_vla_std                 9112 non-null   float64
#  401   second_pts_rank                     9112 non-null   float64
#  402   second_pts_vla                      9112 non-null   float64
#  403   second_pts_vla_std                  9112 non-null   float64
#  404   fbps_rank                           9112 non-null   float64
#  405   fbps_vla                            9112 non-null   float64
#  406   fbps_vla_std                        9112 non-null   float64
#  407   pitp_rank                           9112 non-null   float64
#  408   pitp_vla                            9112 non-null   float64
#  409   pitp_vla_std                        9112 non-null   float64
#  410   opp_pts_off_tov_rank                9112 non-null   float64
#  411   opp_pts_off_tov_vla                 9112 non-null   float64
#  412   opp_pts_off_tov_vla_std             9112 non-null   float64
#  413   opp_second_pts_rank                 9112 non-null   float64
#  414   opp_second_pts_vla                  9112 non-null   float64
#  415   opp_second_pts_vla_std              9112 non-null   float64
#  416   opp_fbps_rank                       9112 non-null   float64
#  417   opp_fbps_vla                        9112 non-null   float64
#  418   opp_fbps_vla_std                    9112 non-null   float64
#  419   opp_pitp_rank                       9112 non-null   float64
#  420   opp_pitp_vla                        9112 non-null   float64
#  421   opp_pitp_vla_std                    9112 non-null   float64
#  422   pts_off_tov_opp                     9112 non-null   float64
#  423   second_pts_opp                      9112 non-null   float64
#  424   fbps_opp                            9112 non-null   float64
#  425   pitp_opp                            9112 non-null   float64
#  426   opp_pts_off_tov_opp                 9112 non-null   float64
#  427   opp_second_pts_opp                  9112 non-null   float64
#  428   opp_fbps_opp                        9112 non-null   float64
#  429   opp_pitp_opp                        9112 non-null   float64
#  430   pts_off_tov_rank_opp                9112 non-null   float64
#  431   pts_off_tov_vla_opp                 9112 non-null   float64
#  432   pts_off_tov_vla_std_opp             9112 non-null   float64
#  433   second_pts_rank_opp                 9112 non-null   float64
#  434   second_pts_vla_opp                  9112 non-null   float64
#  435   second_pts_vla_std_opp              9112 non-null   float64
#  436   fbps_rank_opp                       9112 non-null   float64
#  437   fbps_vla_opp                        9112 non-null   float64
#  438   fbps_vla_std_opp                    9112 non-null   float64
#  439   pitp_rank_opp                       9112 non-null   float64
#  440   pitp_vla_opp                        9112 non-null   float64
#  441   pitp_vla_std_opp                    9112 non-null   float64
#  442   opp_pts_off_tov_rank_opp            9112 non-null   float64
#  443   opp_pts_off_tov_vla_opp             9112 non-null   float64
#  444   opp_pts_off_tov_vla_std_opp         9112 non-null   float64
#  445   opp_second_pts_rank_opp             9112 non-null   float64
#  446   opp_second_pts_vla_opp              9112 non-null   float64
#  447   opp_second_pts_vla_std_opp          9112 non-null   float64
#  448   opp_fbps_rank_opp                   9112 non-null   float64
#  449   opp_fbps_vla_opp                    9112 non-null   float64
#  450   opp_fbps_vla_std_opp                9112 non-null   float64
#  451   opp_pitp_rank_opp                   9112 non-null   float64
#  452   opp_pitp_vla_opp                    9112 non-null   float64
#  453   opp_pitp_vla_std_opp                9112 non-null   float64
#  454   pct_fga_2pt                         9153 non-null   float64
#  455   pct_fga_3pt                         9153 non-null   float64
#  456   pct_pts_2pt                         9153 non-null   float64
#  457   pct_pts_2pt_mid                     9153 non-null   float64
#  458   pct_pts_3pt                         9153 non-null   float64
#  459   pct_pts_fbps                        9153 non-null   float64
#  460   pct_pts_ft                          9153 non-null   float64
#  461   pct_pts_off_tov                     9153 non-null   float64
#  462   pct_pts_pitp                        9153 non-null   float64
#  463   pct_ast_2fgm                        9153 non-null   float64
#  464   pct_uast_2fgm                       9153 non-null   float64
#  465   pct_ast_3fgm                        9153 non-null   float64
#  466   pct_uast_3fgm                       9153 non-null   float64
#  467   pct_ast_fgm                         9153 non-null   float64
#  468   pct_uast_fgm                        9153 non-null   float64
#  469   pct_fga_2pt_rank                    9153 non-null   float64
#  470   pct_fga_2pt_vla                     9153 non-null   float64
#  471   pct_fga_2pt_vla_std                 9153 non-null   float64
#  472   pct_fga_3pt_rank                    9153 non-null   float64
#  473   pct_fga_3pt_vla                     9153 non-null   float64
#  474   pct_fga_3pt_vla_std                 9153 non-null   float64
#  475   pct_pts_2pt_rank                    9153 non-null   float64
#  476   pct_pts_2pt_vla                     9153 non-null   float64
#  477   pct_pts_2pt_vla_std                 9153 non-null   float64
#  478   pct_pts_2pt_mid_rank                9153 non-null   float64
#  479   pct_pts_2pt_mid_vla                 9153 non-null   float64
#  480   pct_pts_2pt_mid_vla_std             9153 non-null   float64
#  481   pct_pts_3pt_rank                    9153 non-null   float64
#  482   pct_pts_3pt_vla                     9153 non-null   float64
#  483   pct_pts_3pt_vla_std                 9153 non-null   float64
#  484   pct_pts_fbps_rank                   9153 non-null   float64
#  485   pct_pts_fbps_vla                    9153 non-null   float64
#  486   pct_pts_fbps_vla_std                9153 non-null   float64
#  487   pct_pts_ft_rank                     9153 non-null   float64
#  488   pct_pts_ft_vla                      9153 non-null   float64
#  489   pct_pts_ft_vla_std                  9153 non-null   float64
#  490   pct_pts_off_tov_rank                9153 non-null   float64
#  491   pct_pts_off_tov_vla                 9153 non-null   float64
#  492   pct_pts_off_tov_vla_std             9153 non-null   float64
#  493   pct_pts_pitp_rank                   9153 non-null   float64
#  494   pct_pts_pitp_vla                    9153 non-null   float64
#  495   pct_pts_pitp_vla_std                9153 non-null   float64
#  496   pct_ast_2fgm_rank                   9153 non-null   float64
#  497   pct_ast_2fgm_vla                    9153 non-null   float64
#  498   pct_ast_2fgm_vla_std                9153 non-null   float64
#  499   pct_uast_2fgm_rank                  9153 non-null   float64
#  500   pct_uast_2fgm_vla                   9153 non-null   float64
#  501   pct_uast_2fgm_vla_std               9153 non-null   float64
#  502   pct_ast_3fgm_rank                   9153 non-null   float64
#  503   pct_ast_3fgm_vla                    9153 non-null   float64
#  504   pct_ast_3fgm_vla_std                9153 non-null   float64
#  505   pct_uast_3fgm_rank                  9153 non-null   float64
#  506   pct_uast_3fgm_vla                   9153 non-null   float64
#  507   pct_uast_3fgm_vla_std               9153 non-null   float64
#  508   pct_ast_fgm_rank                    9153 non-null   float64
#  509   pct_ast_fgm_vla                     9153 non-null   float64
#  510   pct_ast_fgm_vla_std                 9153 non-null   float64
#  511   pct_uast_fgm_rank                   9153 non-null   float64
#  512   pct_uast_fgm_vla                    9153 non-null   float64
#  513   pct_uast_fgm_vla_std                9153 non-null   float64
#  514   pct_fga_2pt_opp                     9153 non-null   float64
#  515   pct_fga_3pt_opp                     9153 non-null   float64
#  516   pct_pts_2pt_opp                     9153 non-null   float64
#  517   pct_pts_2pt_mid_opp                 9153 non-null   float64
#  518   pct_pts_3pt_opp                     9153 non-null   float64
#  519   pct_pts_fbps_opp                    9153 non-null   float64
#  520   pct_pts_ft_opp                      9153 non-null   float64
#  521   pct_pts_off_tov_opp                 9153 non-null   float64
#  522   pct_pts_pitp_opp                    9153 non-null   float64
#  523   pct_ast_2fgm_opp                    9153 non-null   float64
#  524   pct_uast_2fgm_opp                   9153 non-null   float64
#  525   pct_ast_3fgm_opp                    9153 non-null   float64
#  526   pct_uast_3fgm_opp                   9153 non-null   float64
#  527   pct_ast_fgm_opp                     9153 non-null   float64
#  528   pct_uast_fgm_opp                    9153 non-null   float64
#  529   pct_fga_2pt_rank_opp                9153 non-null   float64
#  530   pct_fga_2pt_vla_opp                 9153 non-null   float64
#  531   pct_fga_2pt_vla_std_opp             9153 non-null   float64
#  532   pct_fga_3pt_rank_opp                9153 non-null   float64
#  533   pct_fga_3pt_vla_opp                 9153 non-null   float64
#  534   pct_fga_3pt_vla_std_opp             9153 non-null   float64
#  535   pct_pts_2pt_rank_opp                9153 non-null   float64
#  536   pct_pts_2pt_vla_opp                 9153 non-null   float64
#  537   pct_pts_2pt_vla_std_opp             9153 non-null   float64
#  538   pct_pts_2pt_mid_rank_opp            9153 non-null   float64
#  539   pct_pts_2pt_mid_vla_opp             9153 non-null   float64
#  540   pct_pts_2pt_mid_vla_std_opp         9153 non-null   float64
#  541   pct_pts_3pt_rank_opp                9153 non-null   float64
#  542   pct_pts_3pt_vla_opp                 9153 non-null   float64
#  543   pct_pts_3pt_vla_std_opp             9153 non-null   float64
#  544   pct_pts_fbps_rank_opp               9153 non-null   float64
#  545   pct_pts_fbps_vla_opp                9153 non-null   float64
#  546   pct_pts_fbps_vla_std_opp            9153 non-null   float64
#  547   pct_pts_ft_rank_opp                 9153 non-null   float64
#  548   pct_pts_ft_vla_opp                  9153 non-null   float64
#  549   pct_pts_ft_vla_std_opp              9153 non-null   float64
#  550   pct_pts_off_tov_rank_opp            9153 non-null   float64
#  551   pct_pts_off_tov_vla_opp             9153 non-null   float64
#  552   pct_pts_off_tov_vla_std_opp         9153 non-null   float64
#  553   pct_pts_pitp_rank_opp               9153 non-null   float64
#  554   pct_pts_pitp_vla_opp                9153 non-null   float64
#  555   pct_pts_pitp_vla_std_opp            9153 non-null   float64
#  556   pct_ast_2fgm_rank_opp               9153 non-null   float64
#  557   pct_ast_2fgm_vla_opp                9153 non-null   float64
#  558   pct_ast_2fgm_vla_std_opp            9153 non-null   float64
#  559   pct_uast_2fgm_rank_opp              9153 non-null   float64
#  560   pct_uast_2fgm_vla_opp               9153 non-null   float64
#  561   pct_uast_2fgm_vla_std_opp           9153 non-null   float64
#  562   pct_ast_3fgm_rank_opp               9153 non-null   float64
#  563   pct_ast_3fgm_vla_opp                9153 non-null   float64
#  564   pct_ast_3fgm_vla_std_opp            9153 non-null   float64
#  565   pct_uast_3fgm_rank_opp              9153 non-null   float64
#  566   pct_uast_3fgm_vla_opp               9153 non-null   float64
#  567   pct_uast_3fgm_vla_std_opp           9153 non-null   float64
#  568   pct_ast_fgm_rank_opp                9153 non-null   float64
#  569   pct_ast_fgm_vla_opp                 9153 non-null   float64
#  570   pct_ast_fgm_vla_std_opp             9153 non-null   float64
#  571   pct_uast_fgm_rank_opp               9153 non-null   float64
#  572   pct_uast_fgm_vla_opp                9153 non-null   float64
#  573   pct_uast_fgm_vla_std_opp            9153 non-null   float64
#  574   opp_fgm                             9200 non-null   float64
#  575   opp_fga                             9200 non-null   float64
#  576   opp_fg_pct                          9200 non-null   float64
#  577   opp_3pm                             9200 non-null   float64
#  578   opp_3pa                             9200 non-null   float64
#  579   opp_3pt_pct                         9200 non-null   float64
#  580   opp_ftm                             9200 non-null   float64
#  581   opp_fta                             9200 non-null   float64
#  582   opp_ft_pct                          9200 non-null   float64
#  583   opp_oreb                            9200 non-null   float64
#  584   opp_dreb                            9200 non-null   float64
#  585   opp_reb                             9200 non-null   float64
#  586   opp_ast                             9200 non-null   float64
#  587   opp_tov                             9200 non-null   float64
#  588   opp_stl                             9200 non-null   float64
#  589   opp_blk                             9200 non-null   float64
#  590   opp_blka                            9200 non-null   float64
#  591   opp_pf                              9200 non-null   float64
#  592   opp_pfd                             9200 non-null   float64
#  593   opp_pts                             9200 non-null   float64
#  594   opp_pm                              9200 non-null   float64
#  595   opp_fgm_rank                        9200 non-null   float64
#  596   opp_fgm_vla                         9200 non-null   float64
#  597   opp_fgm_vla_std                     9200 non-null   float64
#  598   opp_fga_rank                        9200 non-null   float64
#  599   opp_fga_vla                         9200 non-null   float64
#  600   opp_fga_vla_std                     9200 non-null   float64
#  601   opp_fg_pct_rank                     9200 non-null   float64
#  602   opp_fg_pct_vla                      9200 non-null   float64
#  603   opp_fg_pct_vla_std                  9200 non-null   float64
#  604   opp_3pm_rank                        9200 non-null   float64
#  605   opp_3pm_vla                         9200 non-null   float64
#  606   opp_3pm_vla_std                     9200 non-null   float64
#  607   opp_3pa_rank                        9200 non-null   float64
#  608   opp_3pa_vla                         9200 non-null   float64
#  609   opp_3pa_vla_std                     9200 non-null   float64
#  610   opp_3pt_pct_rank                    9200 non-null   float64
#  611   opp_3pt_pct_vla                     9200 non-null   float64
#  612   opp_3pt_pct_vla_std                 9200 non-null   float64
#  613   opp_ftm_rank                        9200 non-null   float64
#  614   opp_ftm_vla                         9200 non-null   float64
#  615   opp_ftm_vla_std                     9200 non-null   float64
#  616   opp_fta_rank                        9200 non-null   float64
#  617   opp_fta_vla                         9200 non-null   float64
#  618   opp_fta_vla_std                     9200 non-null   float64
#  619   opp_ft_pct_rank                     9200 non-null   float64
#  620   opp_ft_pct_vla                      9200 non-null   float64
#  621   opp_ft_pct_vla_std                  9200 non-null   float64
#  622   opp_oreb_rank                       9200 non-null   float64
#  623   opp_oreb_vla                        9200 non-null   float64
#  624   opp_oreb_vla_std                    9200 non-null   float64
#  625   opp_dreb_rank                       9200 non-null   float64
#  626   opp_dreb_vla                        9200 non-null   float64
#  627   opp_dreb_vla_std                    9200 non-null   float64
#  628   opp_reb_rank                        9200 non-null   float64
#  629   opp_reb_vla                         9200 non-null   float64
#  630   opp_reb_vla_std                     9200 non-null   float64
#  631   opp_ast_rank                        9200 non-null   float64
#  632   opp_ast_vla                         9200 non-null   float64
#  633   opp_ast_vla_std                     9200 non-null   float64
#  634   opp_tov_rank                        9200 non-null   float64
#  635   opp_tov_vla                         9200 non-null   float64
#  636   opp_tov_vla_std                     9200 non-null   float64
#  637   opp_stl_rank                        9200 non-null   float64
#  638   opp_stl_vla                         9200 non-null   float64
#  639   opp_stl_vla_std                     9200 non-null   float64
#  640   opp_blk_rank                        9200 non-null   float64
#  641   opp_blk_vla                         9200 non-null   float64
#  642   opp_blk_vla_std                     9200 non-null   float64
#  643   opp_blka_rank                       9200 non-null   float64
#  644   opp_blka_vla                        9200 non-null   float64
# ...
#  1015  opp_fgm_lc3_vla                     9200 non-null   float64
#  1016  opp_fgm_lc3_vla_std                 9200 non-null   float64
#  1017  opp_fga_lc3_rank                    9200 non-null   float64
#  1018  opp_fga_lc3_vla                     9200 non-null   float64
#  1019  opp_fga_lc3_vla_std                 9200 non-null   float64
#  1020  opp_fg_pct_lc3_rank                 9200 non-null   float64
#  1021  opp_fg_pct_lc3_vla                  9200 non-null   float64
#  1022  opp_fg_pct_lc3_vla_std              9200 non-null   float64
#  1023  opp_fgm_rc3_rank                    9200 non-null   float64
#  1024  opp_fgm_rc3_vla                     9200 non-null   float64
#  1025  opp_fgm_rc3_vla_std                 9200 non-null   float64
#  1026  opp_fga_rc3_rank                    9200 non-null   float64
#  1027  opp_fga_rc3_vla                     9200 non-null   float64
#  1028  opp_fga_rc3_vla_std                 9200 non-null   float64
#  1029  opp_fg_pct_rc3_rank                 9200 non-null   float64
#  1030  opp_fg_pct_rc3_vla                  9200 non-null   float64
#  1031  opp_fg_pct_rc3_vla_std              9200 non-null   float64
#  1032  opp_fgm_c3_rank                     9200 non-null   float64
#  1033  opp_fgm_c3_vla                      9200 non-null   float64
#  1034  opp_fgm_c3_vla_std                  9200 non-null   float64
#  1035  opp_fga_c3_rank                     9200 non-null   float64
#  1036  opp_fga_c3_vla                      9200 non-null   float64
#  1037  opp_fga_c3_vla_std                  9200 non-null   float64
#  1038  opp_fg_pct_c3_rank                  9200 non-null   float64
#  1039  opp_fg_pct_c3_vla                   9200 non-null   float64
#  1040  opp_fg_pct_c3_vla_std               9200 non-null   float64
#  1041  opp_fgm_atb3_rank                   9200 non-null   float64
#  1042  opp_fgm_atb3_vla                    9200 non-null   float64
#  1043  opp_fgm_atb3_vla_std                9200 non-null   float64
#  1044  opp_fga_atb3_rank                   9200 non-null   float64
#  1045  opp_fga_atb3_vla                    9200 non-null   float64
#  1046  opp_fga_atb3_vla_std                9200 non-null   float64
#  1047  opp_fg_pct_atb3_rank                9200 non-null   float64
#  1048  opp_fg_pct_atb3_vla                 9200 non-null   float64
#  1049  opp_fg_pct_atb3_vla_std             9200 non-null   float64
#  1050  opp_fgm_ra_opp                      9200 non-null   float64
#  1051  opp_fga_ra_opp                      9200 non-null   float64
#  1052  opp_fg_pct_ra_opp                   9200 non-null   float64
#  1053  opp_fgm_paint_opp                   9200 non-null   float64
#  1054  opp_fga_paint_opp                   9200 non-null   float64
#  1055  opp_fg_pct_paint_opp                9200 non-null   float64
#  1056  opp_fgm_mr_opp                      9200 non-null   float64
#  1057  opp_fga_mr_opp                      9200 non-null   float64
#  1058  opp_fg_pct_mr_opp                   9200 non-null   float64
#  1059  opp_fgm_lc3_opp                     9200 non-null   float64
#  1060  opp_fga_lc3_opp                     9200 non-null   float64
#  1061  opp_fg_pct_lc3_opp                  9200 non-null   float64
#  1062  opp_fgm_rc3_opp                     9200 non-null   float64
#  1063  opp_fga_rc3_opp                     9200 non-null   float64
#  1064  opp_fg_pct_rc3_opp                  9200 non-null   float64
#  1065  opp_fgm_c3_opp                      9200 non-null   float64
#  1066  opp_fga_c3_opp                      9200 non-null   float64
#  1067  opp_fg_pct_c3_opp                   9200 non-null   float64
#  1068  opp_fgm_atb3_opp                    9200 non-null   float64
#  1069  opp_fga_atb3_opp                    9200 non-null   float64
#  1070  opp_fg_pct_atb3_opp                 9200 non-null   float64
#  1071  opp_fgm_ra_rank_opp                 9200 non-null   float64
#  1072  opp_fgm_ra_vla_opp                  9200 non-null   float64
#  1073  opp_fgm_ra_vla_std_opp              9200 non-null   float64
#  1074  opp_fga_ra_rank_opp                 9200 non-null   float64
#  1075  opp_fga_ra_vla_opp                  9200 non-null   float64
#  1076  opp_fga_ra_vla_std_opp              9200 non-null   float64
#  1077  opp_fg_pct_ra_rank_opp              9200 non-null   float64
#  1078  opp_fg_pct_ra_vla_opp               9200 non-null   float64
#  1079  opp_fg_pct_ra_vla_std_opp           9200 non-null   float64
#  1080  opp_fgm_paint_rank_opp              9200 non-null   float64
#  1081  opp_fgm_paint_vla_opp               9200 non-null   float64
#  1082  opp_fgm_paint_vla_std_opp           9200 non-null   float64
#  1083  opp_fga_paint_rank_opp              9200 non-null   float64
#  1084  opp_fga_paint_vla_opp               9200 non-null   float64
#  1085  opp_fga_paint_vla_std_opp           9200 non-null   float64
#  1086  opp_fg_pct_paint_rank_opp           9200 non-null   float64
#  1087  opp_fg_pct_paint_vla_opp            9200 non-null   float64
#  1088  opp_fg_pct_paint_vla_std_opp        9200 non-null   float64
#  1089  opp_fgm_mr_rank_opp                 9200 non-null   float64
#  1090  opp_fgm_mr_vla_opp                  9200 non-null   float64
#  1091  opp_fgm_mr_vla_std_opp              9200 non-null   float64
#  1092  opp_fga_mr_rank_opp                 9200 non-null   float64
#  1093  opp_fga_mr_vla_opp                  9200 non-null   float64
#  1094  opp_fga_mr_vla_std_opp              9200 non-null   float64
#  1095  opp_fg_pct_mr_rank_opp              9200 non-null   float64
#  1096  opp_fg_pct_mr_vla_opp               9200 non-null   float64
#  1097  opp_fg_pct_mr_vla_std_opp           9200 non-null   float64
#  1098  opp_fgm_lc3_rank_opp                9200 non-null   float64
#  1099  opp_fgm_lc3_vla_opp                 9200 non-null   float64
#  1100  opp_fgm_lc3_vla_std_opp             9200 non-null   float64
#  1101  opp_fga_lc3_rank_opp                9200 non-null   float64
#  1102  opp_fga_lc3_vla_opp                 9200 non-null   float64
#  1103  opp_fga_lc3_vla_std_opp             9200 non-null   float64
#  1104  opp_fg_pct_lc3_rank_opp             9200 non-null   float64
#  1105  opp_fg_pct_lc3_vla_opp              9200 non-null   float64
#  1106  opp_fg_pct_lc3_vla_std_opp          9200 non-null   float64
#  1107  opp_fgm_rc3_rank_opp                9200 non-null   float64
#  1108  opp_fgm_rc3_vla_opp                 9200 non-null   float64
#  1109  opp_fgm_rc3_vla_std_opp             9200 non-null   float64
#  1110  opp_fga_rc3_rank_opp                9200 non-null   float64
#  1111  opp_fga_rc3_vla_opp                 9200 non-null   float64
#  1112  opp_fga_rc3_vla_std_opp             9200 non-null   float64
#  1113  opp_fg_pct_rc3_rank_opp             9200 non-null   float64
#  1114  opp_fg_pct_rc3_vla_opp              9200 non-null   float64
#  1115  opp_fg_pct_rc3_vla_std_opp          9200 non-null   float64
#  1116  opp_fgm_c3_rank_opp                 9200 non-null   float64
#  1117  opp_fgm_c3_vla_opp                  9200 non-null   float64
#  1118  opp_fgm_c3_vla_std_opp              9200 non-null   float64
#  1119  opp_fga_c3_rank_opp                 9200 non-null   float64
#  1120  opp_fga_c3_vla_opp                  9200 non-null   float64
#  1121  opp_fga_c3_vla_std_opp              9200 non-null   float64
#  1122  opp_fg_pct_c3_rank_opp              9200 non-null   float64
#  1123  opp_fg_pct_c3_vla_opp               9200 non-null   float64
#  1124  opp_fg_pct_c3_vla_std_opp           9200 non-null   float64
#  1125  opp_fgm_atb3_rank_opp               9200 non-null   float64
#  1126  opp_fgm_atb3_vla_opp                9200 non-null   float64
#  1127  opp_fgm_atb3_vla_std_opp            9200 non-null   float64
#  1128  opp_fga_atb3_rank_opp               9200 non-null   float64
#  1129  opp_fga_atb3_vla_opp                9200 non-null   float64
#  1130  opp_fga_atb3_vla_std_opp            9200 non-null   float64
#  1131  opp_fg_pct_atb3_rank_opp            9200 non-null   float64
#  1132  opp_fg_pct_atb3_vla_opp             9200 non-null   float64
#  1133  opp_fg_pct_atb3_vla_std_opp         9200 non-null   float64
#  1134  screen_ast                          7070 non-null   float64
#  1135  screen_ast_pts                      7070 non-null   float64
#  1136  deflections                         7070 non-null   float64
#  1137  off_loose_ball_rec                  7070 non-null   float64
#  1138  def_loose_ball_rec                  7070 non-null   float64
#  1139  loose_ball_rec                      7070 non-null   float64
#  1140  pct_loose_ball_rec_off              7070 non-null   float64
#  1141  pct_loose_ball_rec_def              7070 non-null   float64
#  1142  charges_drawn                       7070 non-null   float64
#  1143  contested_2pt                       7070 non-null   float64
#  1144  contested_3pt                       7070 non-null   float64
#  1145  contested_shots                     7070 non-null   float64
#  1146  screen_ast_rank                     7070 non-null   float64
#  1147  screen_ast_vla                      7070 non-null   float64
#  1148  screen_ast_vla_std                  7070 non-null   float64
#  1149  screen_ast_pts_rank                 7070 non-null   float64
#  1150  screen_ast_pts_vla                  7070 non-null   float64
#  1151  screen_ast_pts_vla_std              7070 non-null   float64
#  1152  deflections_rank                    7070 non-null   float64
#  1153  deflections_vla                     7070 non-null   float64
#  1154  deflections_vla_std                 7070 non-null   float64
#  1155  off_loose_ball_rec_rank             7070 non-null   float64
#  1156  off_loose_ball_rec_vla              7070 non-null   float64
#  1157  off_loose_ball_rec_vla_std          5631 non-null   float64
#  1158  def_loose_ball_rec_rank             7070 non-null   float64
#  1159  def_loose_ball_rec_vla              7070 non-null   float64
#  1160  def_loose_ball_rec_vla_std          5631 non-null   float64
#  1161  loose_ball_rec_rank                 7070 non-null   float64
#  1162  loose_ball_rec_vla                  7070 non-null   float64
#  1163  loose_ball_rec_vla_std              7070 non-null   float64
#  1164  pct_loose_ball_rec_off_rank         7070 non-null   float64
#  1165  pct_loose_ball_rec_off_vla          7070 non-null   float64
#  1166  pct_loose_ball_rec_off_vla_std      5631 non-null   float64
#  1167  pct_loose_ball_rec_def_rank         7070 non-null   float64
#  1168  pct_loose_ball_rec_def_vla          7070 non-null   float64
#  1169  pct_loose_ball_rec_def_vla_std      5631 non-null   float64
#  1170  charges_drawn_rank                  7070 non-null   float64
#  1171  charges_drawn_vla                   7070 non-null   float64
#  1172  charges_drawn_vla_std               7070 non-null   float64
#  1173  contested_2pt_rank                  7070 non-null   float64
#  1174  contested_2pt_vla                   7070 non-null   float64
#  1175  contested_2pt_vla_std               7070 non-null   float64
#  1176  contested_3pt_rank                  7070 non-null   float64
#  1177  contested_3pt_vla                   7070 non-null   float64
#  1178  contested_3pt_vla_std               7070 non-null   float64
#  1179  contested_shots_rank                7070 non-null   float64
#  1180  contested_shots_vla                 7070 non-null   float64
#  1181  contested_shots_vla_std             7070 non-null   float64
#  1182  screen_ast_opp                      7070 non-null   float64
#  1183  screen_ast_pts_opp                  7070 non-null   float64
#  1184  deflections_opp                     7070 non-null   float64
#  1185  off_loose_ball_rec_opp              7070 non-null   float64
#  1186  def_loose_ball_rec_opp              7070 non-null   float64
#  1187  loose_ball_rec_opp                  7070 non-null   float64
#  1188  pct_loose_ball_rec_off_opp          7070 non-null   float64
#  1189  pct_loose_ball_rec_def_opp          7070 non-null   float64
#  1190  charges_drawn_opp                   7070 non-null   float64
#  1191  contested_2pt_opp                   7070 non-null   float64
#  1192  contested_3pt_opp                   7070 non-null   float64
#  1193  contested_shots_opp                 7070 non-null   float64
#  1194  screen_ast_rank_opp                 7070 non-null   float64
#  1195  screen_ast_vla_opp                  7070 non-null   float64
#  1196  screen_ast_vla_std_opp              7070 non-null   float64
#  1197  screen_ast_pts_rank_opp             7070 non-null   float64
#  1198  screen_ast_pts_vla_opp              7070 non-null   float64
#  1199  screen_ast_pts_vla_std_opp          7070 non-null   float64
#  1200  deflections_rank_opp                7070 non-null   float64
#  1201  deflections_vla_opp                 7070 non-null   float64
#  1202  deflections_vla_std_opp             7070 non-null   float64
#  1203  off_loose_ball_rec_rank_opp         7070 non-null   float64
#  1204  off_loose_ball_rec_vla_opp          7070 non-null   float64
#  1205  off_loose_ball_rec_vla_std_opp      5631 non-null   float64
#  1206  def_loose_ball_rec_rank_opp         7070 non-null   float64
#  1207  def_loose_ball_rec_vla_opp          7070 non-null   float64
#  1208  def_loose_ball_rec_vla_std_opp      5631 non-null   float64
#  1209  loose_ball_rec_rank_opp             7070 non-null   float64
#  1210  loose_ball_rec_vla_opp              7070 non-null   float64
#  1211  loose_ball_rec_vla_std_opp          7070 non-null   float64
#  1212  pct_loose_ball_rec_off_rank_opp     7070 non-null   float64
#  1213  pct_loose_ball_rec_off_vla_opp      7070 non-null   float64
#  1214  pct_loose_ball_rec_off_vla_std_opp  5631 non-null   float64
#  1215  pct_loose_ball_rec_def_rank_opp     7070 non-null   float64
#  1216  pct_loose_ball_rec_def_vla_opp      7070 non-null   float64
#  1217  pct_loose_ball_rec_def_vla_std_opp  5631 non-null   float64
#  1218  charges_drawn_rank_opp              7070 non-null   float64
#  1219  charges_drawn_vla_opp               7070 non-null   float64
#  1220  charges_drawn_vla_std_opp           7070 non-null   float64
#  1221  contested_2pt_rank_opp              7070 non-null   float64
#  1222  contested_2pt_vla_opp               7070 non-null   float64
#  1223  contested_2pt_vla_std_opp           7070 non-null   float64
#  1224  contested_3pt_rank_opp              7070 non-null   float64
#  1225  contested_3pt_vla_opp               7070 non-null   float64
#  1226  contested_3pt_vla_std_opp           7070 non-null   float64
#  1227  contested_shots_rank_opp            7070 non-null   float64
#  1228  contested_shots_vla_opp             7070 non-null   float64
#  1229  contested_shots_vla_std_opp         7070 non-null   float64
# dtypes: datetime64[ns](2), float64(1221), object(7)
# memory usage: 86.4+ MB

# %% [markdown]
# ## Set Datatypes

# %%
for column in list(full_dataset):
    if full_dataset[column].dtype == 'float64':
        full_dataset[column] = pd.to_numeric(full_dataset[column], downcast='float')
    if full_dataset[column].dtype == 'int64':
        full_dataset[column] = pd.to_numeric(full_dataset[column], downcast='integer')

# %%
full_dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9200 entries, 11 to 20042
# Data columns (total 1230 columns):
#  #     Column                              Dtype
# ---    ------                              -----
#  0     game_id                             object
#  1     game_date                           datetime64[ns]
#  2     home_team                           object
#  3     away_team                           object
#  4     home_score                          float32
#  5     away_score                          float32
#  6     home_result                         object
#  7     league_year                         object
#  8     pred_date                           datetime64[ns]
#  9     home_spread                         float32
#  10    home_spread_result                  object
#  11    covers_game_url                     object
#  12    fd_line_home                        float32
#  13    fd_line_price_home                  float32
#  14    fd_line_away                        float32
#  15    fd_line_price_away                  float32
#  16    dk_line_home                        float32
#  17    dk_line_price_home                  float32
#  18    dk_line_away                        float32
#  19    dk_line_price_away                  float32
#  20    covers_consenses_home               float32
#  21    covers_consenses_away               float32
#  22    gp                                  float32
#  23    win                                 float32
#  24    loss                                float32
#  25    w_pct                               float32
#  26    mins                                float32
#  27    pts                                 float32
#  28    fgm                                 float32
#  29    fga                                 float32
#  30    fg_pct                              float32
#  31    fg3m                                float32
#  32    fg3a                                float32
#  33    fg3_pct                             float32
#  34    ftm                                 float32
#  35    fta                                 float32
#  36    ft_pct                              float32
#  37    oreb                                float32
#  38    dreb                                float32
#  39    reb                                 float32
#  40    ast                                 float32
#  41    tov                                 float32
#  42    stl                                 float32
#  43    blk                                 float32
#  44    blka                                float32
#  45    pf                                  float32
#  46    pfd                                 float32
#  47    p_m                                 float32
#  48    gp_rank                             float32
#  49    gp_vla                              float32
#  50    gp_vla_std                          float32
#  51    win_rank                            float32
#  52    win_vla                             float32
#  53    win_vla_std                         float32
#  54    loss_rank                           float32
#  55    loss_vla                            float32
#  56    loss_vla_std                        float32
#  57    w_pct_rank                          float32
#  58    w_pct_vla                           float32
#  59    w_pct_vla_std                       float32
#  60    mins_rank                           float32
#  61    mins_vla                            float32
#  62    mins_vla_std                        float32
#  63    pts_rank                            float32
#  64    pts_vla                             float32
#  65    pts_vla_std                         float32
#  66    fgm_rank                            float32
#  67    fgm_vla                             float32
#  68    fgm_vla_std                         float32
#  69    fga_rank                            float32
#  70    fga_vla                             float32
#  71    fga_vla_std                         float32
#  72    fg_pct_rank                         float32
#  73    fg_pct_vla                          float32
#  74    fg_pct_vla_std                      float32
#  75    fg3m_rank                           float32
#  76    fg3m_vla                            float32
#  77    fg3m_vla_std                        float32
#  78    fg3a_rank                           float32
#  79    fg3a_vla                            float32
#  80    fg3a_vla_std                        float32
#  81    fg3_pct_rank                        float32
#  82    fg3_pct_vla                         float32
#  83    fg3_pct_vla_std                     float32
#  84    ftm_rank                            float32
#  85    ftm_vla                             float32
#  86    ftm_vla_std                         float32
#  87    fta_rank                            float32
#  88    fta_vla                             float32
#  89    fta_vla_std                         float32
#  90    ft_pct_rank                         float32
#  91    ft_pct_vla                          float32
#  92    ft_pct_vla_std                      float32
#  93    oreb_rank                           float32
#  94    oreb_vla                            float32
#  95    oreb_vla_std                        float32
#  96    dreb_rank                           float32
#  97    dreb_vla                            float32
#  98    dreb_vla_std                        float32
#  99    reb_rank                            float32
#  100   reb_vla                             float32
#  101   reb_vla_std                         float32
#  102   ast_rank                            float32
#  103   ast_vla                             float32
#  104   ast_vla_std                         float32
#  105   tov_rank                            float32
#  106   tov_vla                             float32
#  107   tov_vla_std                         float32
#  108   stl_rank                            float32
#  109   stl_vla                             float32
#  110   stl_vla_std                         float32
#  111   blk_rank                            float32
#  112   blk_vla                             float32
#  113   blk_vla_std                         float32
#  114   blka_rank                           float32
#  115   blka_vla                            float32
#  116   blka_vla_std                        float32
#  117   pf_rank                             float32
#  118   pf_vla                              float32
#  119   pf_vla_std                          float32
#  120   pfd_rank                            float32
#  121   pfd_vla                             float32
#  122   pfd_vla_std                         float32
#  123   p_m_rank                            float32
#  124   p_m_vla                             float32
#  125   p_m_vla_std                         float32
#  126   gp_opp                              float32
#  127   win_opp                             float32
#  128   loss_opp                            float32
#  129   w_pct_opp                           float32
#  130   mins_opp                            float32
#  131   pts_opp                             float32
#  132   fgm_opp                             float32
#  133   fga_opp                             float32
#  134   fg_pct_opp                          float32
#  135   fg3m_opp                            float32
#  136   fg3a_opp                            float32
#  137   fg3_pct_opp                         float32
#  138   ftm_opp                             float32
#  139   fta_opp                             float32
#  140   ft_pct_opp                          float32
#  141   oreb_opp                            float32
#  142   dreb_opp                            float32
#  143   reb_opp                             float32
#  144   ast_opp                             float32
#  145   tov_opp                             float32
#  146   stl_opp                             float32
#  147   blk_opp                             float32
#  148   blka_opp                            float32
#  149   pf_opp                              float32
#  150   pfd_opp                             float32
#  151   p_m_opp                             float32
#  152   gp_rank_opp                         float32
#  153   gp_vla_opp                          float32
#  154   gp_vla_std_opp                      float32
#  155   win_rank_opp                        float32
#  156   win_vla_opp                         float32
#  157   win_vla_std_opp                     float32
#  158   loss_rank_opp                       float32
#  159   loss_vla_opp                        float32
#  160   loss_vla_std_opp                    float32
#  161   w_pct_rank_opp                      float32
#  162   w_pct_vla_opp                       float32
#  163   w_pct_vla_std_opp                   float32
#  164   mins_rank_opp                       float32
#  165   mins_vla_opp                        float32
#  166   mins_vla_std_opp                    float32
#  167   pts_rank_opp                        float32
#  168   pts_vla_opp                         float32
#  169   pts_vla_std_opp                     float32
#  170   fgm_rank_opp                        float32
#  171   fgm_vla_opp                         float32
#  172   fgm_vla_std_opp                     float32
#  173   fga_rank_opp                        float32
#  174   fga_vla_opp                         float32
#  175   fga_vla_std_opp                     float32
#  176   fg_pct_rank_opp                     float32
#  177   fg_pct_vla_opp                      float32
#  178   fg_pct_vla_std_opp                  float32
#  179   fg3m_rank_opp                       float32
#  180   fg3m_vla_opp                        float32
#  181   fg3m_vla_std_opp                    float32
#  182   fg3a_rank_opp                       float32
#  183   fg3a_vla_opp                        float32
#  184   fg3a_vla_std_opp                    float32
#  185   fg3_pct_rank_opp                    float32
#  186   fg3_pct_vla_opp                     float32
#  187   fg3_pct_vla_std_opp                 float32
#  188   ftm_rank_opp                        float32
#  189   ftm_vla_opp                         float32
#  190   ftm_vla_std_opp                     float32
#  191   fta_rank_opp                        float32
#  192   fta_vla_opp                         float32
#  193   fta_vla_std_opp                     float32
#  194   ft_pct_rank_opp                     float32
#  195   ft_pct_vla_opp                      float32
#  196   ft_pct_vla_std_opp                  float32
#  197   oreb_rank_opp                       float32
#  198   oreb_vla_opp                        float32
#  199   oreb_vla_std_opp                    float32
#  200   dreb_rank_opp                       float32
#  201   dreb_vla_opp                        float32
#  202   dreb_vla_std_opp                    float32
#  203   reb_rank_opp                        float32
#  204   reb_vla_opp                         float32
#  205   reb_vla_std_opp                     float32
#  206   ast_rank_opp                        float32
#  207   ast_vla_opp                         float32
#  208   ast_vla_std_opp                     float32
#  209   tov_rank_opp                        float32
#  210   tov_vla_opp                         float32
#  211   tov_vla_std_opp                     float32
#  212   stl_rank_opp                        float32
#  213   stl_vla_opp                         float32
#  214   stl_vla_std_opp                     float32
#  215   blk_rank_opp                        float32
#  216   blk_vla_opp                         float32
#  217   blk_vla_std_opp                     float32
#  218   blka_rank_opp                       float32
#  219   blka_vla_opp                        float32
#  220   blka_vla_std_opp                    float32
#  221   pf_rank_opp                         float32
#  222   pf_vla_opp                          float32
#  223   pf_vla_std_opp                      float32
#  224   pfd_rank_opp                        float32
#  225   pfd_vla_opp                         float32
#  226   pfd_vla_std_opp                     float32
#  227   p_m_rank_opp                        float32
#  228   p_m_vla_opp                         float32
#  229   p_m_vla_std_opp                     float32
#  230   offrtg                              float32
#  231   defrtg                              float32
#  232   netrtg                              float32
#  233   ast_pct                             float32
#  234   ast_v_tov                           float32
#  235   ast_ratio                           float32
#  236   oreb_pct                            float32
#  237   dreb_pct                            float32
#  238   reb_pct                             float32
#  239   tov_pct                             float32
#  240   efg_pct                             float32
#  241   ts_pct                              float32
#  242   pace                                float32
#  243   pie                                 float32
#  244   poss                                float32
#  245   offrtg_rank                         float32
#  246   offrtg_vla                          float32
#  247   offrtg_vla_std                      float32
#  248   defrtg_rank                         float32
#  249   defrtg_vla                          float32
#  250   defrtg_vla_std                      float32
#  251   netrtg_rank                         float32
#  252   netrtg_vla                          float32
#  253   netrtg_vla_std                      float32
#  254   ast_pct_rank                        float32
#  255   ast_pct_vla                         float32
#  256   ast_pct_vla_std                     float32
#  257   ast_v_tov_rank                      float32
#  258   ast_v_tov_vla                       float32
#  259   ast_v_tov_vla_std                   float32
#  260   ast_ratio_rank                      float32
#  261   ast_ratio_vla                       float32
#  262   ast_ratio_vla_std                   float32
#  263   oreb_pct_rank                       float32
#  264   oreb_pct_vla                        float32
#  265   oreb_pct_vla_std                    float32
#  266   dreb_pct_rank                       float32
#  267   dreb_pct_vla                        float32
#  268   dreb_pct_vla_std                    float32
#  269   reb_pct_rank                        float32
#  270   reb_pct_vla                         float32
#  271   reb_pct_vla_std                     float32
#  272   tov_pct_rank                        float32
#  273   tov_pct_vla                         float32
#  274   tov_pct_vla_std                     float32
#  275   efg_pct_rank                        float32
#  276   efg_pct_vla                         float32
#  277   efg_pct_vla_std                     float32
#  278   ts_pct_rank                         float32
#  279   ts_pct_vla                          float32
#  280   ts_pct_vla_std                      float32
#  281   pace_rank                           float32
#  282   pace_vla                            float32
#  283   pace_vla_std                        float32
#  284   pie_rank                            float32
#  285   pie_vla                             float32
#  286   pie_vla_std                         float32
#  287   poss_rank                           float32
#  288   poss_vla                            float32
#  289   poss_vla_std                        float32
#  290   offrtg_opp                          float32
#  291   defrtg_opp                          float32
#  292   netrtg_opp                          float32
#  293   ast_pct_opp                         float32
#  294   ast_v_tov_opp                       float32
#  295   ast_ratio_opp                       float32
#  296   oreb_pct_opp                        float32
#  297   dreb_pct_opp                        float32
#  298   reb_pct_opp                         float32
#  299   tov_pct_opp                         float32
#  300   efg_pct_opp                         float32
#  301   ts_pct_opp                          float32
#  302   pace_opp                            float32
#  303   pie_opp                             float32
#  304   poss_opp                            float32
#  305   offrtg_rank_opp                     float32
#  306   offrtg_vla_opp                      float32
#  307   offrtg_vla_std_opp                  float32
#  308   defrtg_rank_opp                     float32
#  309   defrtg_vla_opp                      float32
#  310   defrtg_vla_std_opp                  float32
#  311   netrtg_rank_opp                     float32
#  312   netrtg_vla_opp                      float32
#  313   netrtg_vla_std_opp                  float32
#  314   ast_pct_rank_opp                    float32
#  315   ast_pct_vla_opp                     float32
#  316   ast_pct_vla_std_opp                 float32
#  317   ast_v_tov_rank_opp                  float32
#  318   ast_v_tov_vla_opp                   float32
#  319   ast_v_tov_vla_std_opp               float32
#  320   ast_ratio_rank_opp                  float32
#  321   ast_ratio_vla_opp                   float32
#  322   ast_ratio_vla_std_opp               float32
#  323   oreb_pct_rank_opp                   float32
#  324   oreb_pct_vla_opp                    float32
#  325   oreb_pct_vla_std_opp                float32
#  326   dreb_pct_rank_opp                   float32
#  327   dreb_pct_vla_opp                    float32
#  328   dreb_pct_vla_std_opp                float32
#  329   reb_pct_rank_opp                    float32
#  330   reb_pct_vla_opp                     float32
#  331   reb_pct_vla_std_opp                 float32
#  332   tov_pct_rank_opp                    float32
#  333   tov_pct_vla_opp                     float32
#  334   tov_pct_vla_std_opp                 float32
#  335   efg_pct_rank_opp                    float32
#  336   efg_pct_vla_opp                     float32
#  337   efg_pct_vla_std_opp                 float32
#  338   ts_pct_rank_opp                     float32
#  339   ts_pct_vla_opp                      float32
#  340   ts_pct_vla_std_opp                  float32
#  341   pace_rank_opp                       float32
#  342   pace_vla_opp                        float32
#  343   pace_vla_std_opp                    float32
#  344   pie_rank_opp                        float32
#  345   pie_vla_opp                         float32
#  346   pie_vla_std_opp                     float32
#  347   poss_rank_opp                       float32
#  348   poss_vla_opp                        float32
#  349   poss_vla_std_opp                    float32
#  350   fta_rate                            float32
#  351   opp_efg_pct                         float32
#  352   opp_fta_rate                        float32
#  353   opp_tov_pct                         float32
#  354   opp_oreb_pct                        float32
#  355   fta_rate_rank                       float32
#  356   fta_rate_vla                        float32
#  357   fta_rate_vla_std                    float32
#  358   opp_efg_pct_rank                    float32
#  359   opp_efg_pct_vla                     float32
#  360   opp_efg_pct_vla_std                 float32
#  361   opp_fta_rate_rank                   float32
#  362   opp_fta_rate_vla                    float32
#  363   opp_fta_rate_vla_std                float32
#  364   opp_tov_pct_rank                    float32
#  365   opp_tov_pct_vla                     float32
#  366   opp_tov_pct_vla_std                 float32
#  367   opp_oreb_pct_rank                   float32
#  368   opp_oreb_pct_vla                    float32
#  369   opp_oreb_pct_vla_std                float32
#  370   fta_rate_opp                        float32
#  371   opp_efg_pct_opp                     float32
#  372   opp_fta_rate_opp                    float32
#  373   opp_tov_pct_opp                     float32
#  374   opp_oreb_pct_opp                    float32
#  375   fta_rate_rank_opp                   float32
#  376   fta_rate_vla_opp                    float32
#  377   fta_rate_vla_std_opp                float32
#  378   opp_efg_pct_rank_opp                float32
#  379   opp_efg_pct_vla_opp                 float32
#  380   opp_efg_pct_vla_std_opp             float32
#  381   opp_fta_rate_rank_opp               float32
#  382   opp_fta_rate_vla_opp                float32
#  383   opp_fta_rate_vla_std_opp            float32
#  384   opp_tov_pct_rank_opp                float32
#  385   opp_tov_pct_vla_opp                 float32
#  386   opp_tov_pct_vla_std_opp             float32
#  387   opp_oreb_pct_rank_opp               float32
#  388   opp_oreb_pct_vla_opp                float32
#  389   opp_oreb_pct_vla_std_opp            float32
#  390   pts_off_tov                         float32
#  391   second_pts                          float32
#  392   fbps                                float32
#  393   pitp                                float32
#  394   opp_pts_off_tov                     float32
#  395   opp_second_pts                      float32
#  396   opp_fbps                            float32
#  397   opp_pitp                            float32
#  398   pts_off_tov_rank                    float32
#  399   pts_off_tov_vla                     float32
#  400   pts_off_tov_vla_std                 float32
#  401   second_pts_rank                     float32
#  402   second_pts_vla                      float32
#  403   second_pts_vla_std                  float32
#  404   fbps_rank                           float32
#  405   fbps_vla                            float32
#  406   fbps_vla_std                        float32
#  407   pitp_rank                           float32
#  408   pitp_vla                            float32
#  409   pitp_vla_std                        float32
#  410   opp_pts_off_tov_rank                float32
#  411   opp_pts_off_tov_vla                 float32
#  412   opp_pts_off_tov_vla_std             float32
#  413   opp_second_pts_rank                 float32
#  414   opp_second_pts_vla                  float32
#  415   opp_second_pts_vla_std              float32
#  416   opp_fbps_rank                       float32
#  417   opp_fbps_vla                        float32
#  418   opp_fbps_vla_std                    float32
#  419   opp_pitp_rank                       float32
#  420   opp_pitp_vla                        float32
#  421   opp_pitp_vla_std                    float32
#  422   pts_off_tov_opp                     float32
#  423   second_pts_opp                      float32
#  424   fbps_opp                            float32
#  425   pitp_opp                            float32
#  426   opp_pts_off_tov_opp                 float32
#  427   opp_second_pts_opp                  float32
#  428   opp_fbps_opp                        float32
#  429   opp_pitp_opp                        float32
#  430   pts_off_tov_rank_opp                float32
#  431   pts_off_tov_vla_opp                 float32
#  432   pts_off_tov_vla_std_opp             float32
#  433   second_pts_rank_opp                 float32
#  434   second_pts_vla_opp                  float32
#  435   second_pts_vla_std_opp              float32
#  436   fbps_rank_opp                       float32
#  437   fbps_vla_opp                        float32
#  438   fbps_vla_std_opp                    float32
#  439   pitp_rank_opp                       float32
#  440   pitp_vla_opp                        float32
#  441   pitp_vla_std_opp                    float32
#  442   opp_pts_off_tov_rank_opp            float32
#  443   opp_pts_off_tov_vla_opp             float32
#  444   opp_pts_off_tov_vla_std_opp         float32
#  445   opp_second_pts_rank_opp             float32
#  446   opp_second_pts_vla_opp              float32
#  447   opp_second_pts_vla_std_opp          float32
#  448   opp_fbps_rank_opp                   float32
#  449   opp_fbps_vla_opp                    float32
#  450   opp_fbps_vla_std_opp                float32
#  451   opp_pitp_rank_opp                   float32
#  452   opp_pitp_vla_opp                    float32
#  453   opp_pitp_vla_std_opp                float32
#  454   pct_fga_2pt                         float32
#  455   pct_fga_3pt                         float32
#  456   pct_pts_2pt                         float32
#  457   pct_pts_2pt_mid                     float32
#  458   pct_pts_3pt                         float32
#  459   pct_pts_fbps                        float32
#  460   pct_pts_ft                          float32
#  461   pct_pts_off_tov                     float32
#  462   pct_pts_pitp                        float32
#  463   pct_ast_2fgm                        float32
#  464   pct_uast_2fgm                       float32
#  465   pct_ast_3fgm                        float32
#  466   pct_uast_3fgm                       float32
#  467   pct_ast_fgm                         float32
#  468   pct_uast_fgm                        float32
#  469   pct_fga_2pt_rank                    float32
#  470   pct_fga_2pt_vla                     float32
#  471   pct_fga_2pt_vla_std                 float32
#  472   pct_fga_3pt_rank                    float32
#  473   pct_fga_3pt_vla                     float32
#  474   pct_fga_3pt_vla_std                 float32
#  475   pct_pts_2pt_rank                    float32
#  476   pct_pts_2pt_vla                     float32
#  477   pct_pts_2pt_vla_std                 float32
#  478   pct_pts_2pt_mid_rank                float32
#  479   pct_pts_2pt_mid_vla                 float32
#  480   pct_pts_2pt_mid_vla_std             float32
#  481   pct_pts_3pt_rank                    float32
#  482   pct_pts_3pt_vla                     float32
#  483   pct_pts_3pt_vla_std                 float32
#  484   pct_pts_fbps_rank                   float32
#  485   pct_pts_fbps_vla                    float32
#  486   pct_pts_fbps_vla_std                float32
#  487   pct_pts_ft_rank                     float32
#  488   pct_pts_ft_vla                      float32
#  489   pct_pts_ft_vla_std                  float32
#  490   pct_pts_off_tov_rank                float32
#  491   pct_pts_off_tov_vla                 float32
#  492   pct_pts_off_tov_vla_std             float32
#  493   pct_pts_pitp_rank                   float32
#  494   pct_pts_pitp_vla                    float32
#  495   pct_pts_pitp_vla_std                float32
#  496   pct_ast_2fgm_rank                   float32
#  497   pct_ast_2fgm_vla                    float32
#  498   pct_ast_2fgm_vla_std                float32
#  499   pct_uast_2fgm_rank                  float32
#  500   pct_uast_2fgm_vla                   float32
#  501   pct_uast_2fgm_vla_std               float32
#  502   pct_ast_3fgm_rank                   float32
#  503   pct_ast_3fgm_vla                    float32
#  504   pct_ast_3fgm_vla_std                float32
#  505   pct_uast_3fgm_rank                  float32
#  506   pct_uast_3fgm_vla                   float32
#  507   pct_uast_3fgm_vla_std               float32
#  508   pct_ast_fgm_rank                    float32
#  509   pct_ast_fgm_vla                     float32
#  510   pct_ast_fgm_vla_std                 float32
#  511   pct_uast_fgm_rank                   float32
#  512   pct_uast_fgm_vla                    float32
#  513   pct_uast_fgm_vla_std                float32
#  514   pct_fga_2pt_opp                     float32
#  515   pct_fga_3pt_opp                     float32
#  516   pct_pts_2pt_opp                     float32
#  517   pct_pts_2pt_mid_opp                 float32
#  518   pct_pts_3pt_opp                     float32
#  519   pct_pts_fbps_opp                    float32
#  520   pct_pts_ft_opp                      float32
#  521   pct_pts_off_tov_opp                 float32
#  522   pct_pts_pitp_opp                    float32
#  523   pct_ast_2fgm_opp                    float32
#  524   pct_uast_2fgm_opp                   float32
#  525   pct_ast_3fgm_opp                    float32
#  526   pct_uast_3fgm_opp                   float32
#  527   pct_ast_fgm_opp                     float32
#  528   pct_uast_fgm_opp                    float32
#  529   pct_fga_2pt_rank_opp                float32
#  530   pct_fga_2pt_vla_opp                 float32
#  531   pct_fga_2pt_vla_std_opp             float32
#  532   pct_fga_3pt_rank_opp                float32
#  533   pct_fga_3pt_vla_opp                 float32
#  534   pct_fga_3pt_vla_std_opp             float32
#  535   pct_pts_2pt_rank_opp                float32
#  536   pct_pts_2pt_vla_opp                 float32
#  537   pct_pts_2pt_vla_std_opp             float32
#  538   pct_pts_2pt_mid_rank_opp            float32
#  539   pct_pts_2pt_mid_vla_opp             float32
#  540   pct_pts_2pt_mid_vla_std_opp         float32
#  541   pct_pts_3pt_rank_opp                float32
#  542   pct_pts_3pt_vla_opp                 float32
#  543   pct_pts_3pt_vla_std_opp             float32
#  544   pct_pts_fbps_rank_opp               float32
#  545   pct_pts_fbps_vla_opp                float32
#  546   pct_pts_fbps_vla_std_opp            float32
#  547   pct_pts_ft_rank_opp                 float32
#  548   pct_pts_ft_vla_opp                  float32
#  549   pct_pts_ft_vla_std_opp              float32
#  550   pct_pts_off_tov_rank_opp            float32
#  551   pct_pts_off_tov_vla_opp             float32
#  552   pct_pts_off_tov_vla_std_opp         float32
#  553   pct_pts_pitp_rank_opp               float32
#  554   pct_pts_pitp_vla_opp                float32
#  555   pct_pts_pitp_vla_std_opp            float32
#  556   pct_ast_2fgm_rank_opp               float32
#  557   pct_ast_2fgm_vla_opp                float32
#  558   pct_ast_2fgm_vla_std_opp            float32
#  559   pct_uast_2fgm_rank_opp              float32
#  560   pct_uast_2fgm_vla_opp               float32
#  561   pct_uast_2fgm_vla_std_opp           float32
#  562   pct_ast_3fgm_rank_opp               float32
#  563   pct_ast_3fgm_vla_opp                float32
#  564   pct_ast_3fgm_vla_std_opp            float32
#  565   pct_uast_3fgm_rank_opp              float32
#  566   pct_uast_3fgm_vla_opp               float32
#  567   pct_uast_3fgm_vla_std_opp           float32
#  568   pct_ast_fgm_rank_opp                float32
#  569   pct_ast_fgm_vla_opp                 float32
#  570   pct_ast_fgm_vla_std_opp             float32
#  571   pct_uast_fgm_rank_opp               float32
#  572   pct_uast_fgm_vla_opp                float32
#  573   pct_uast_fgm_vla_std_opp            float32
#  574   opp_fgm                             float32
#  575   opp_fga                             float32
#  576   opp_fg_pct                          float32
#  577   opp_3pm                             float32
#  578   opp_3pa                             float32
#  579   opp_3pt_pct                         float32
#  580   opp_ftm                             float32
#  581   opp_fta                             float32
#  582   opp_ft_pct                          float32
#  583   opp_oreb                            float32
#  584   opp_dreb                            float32
#  585   opp_reb                             float32
#  586   opp_ast                             float32
#  587   opp_tov                             float32
#  588   opp_stl                             float32
#  589   opp_blk                             float32
#  590   opp_blka                            float32
#  591   opp_pf                              float32
#  592   opp_pfd                             float32
#  593   opp_pts                             float32
#  594   opp_pm                              float32
#  595   opp_fgm_rank                        float32
#  596   opp_fgm_vla                         float32
#  597   opp_fgm_vla_std                     float32
#  598   opp_fga_rank                        float32
#  599   opp_fga_vla                         float32
#  600   opp_fga_vla_std                     float32
#  601   opp_fg_pct_rank                     float32
#  602   opp_fg_pct_vla                      float32
#  603   opp_fg_pct_vla_std                  float32
#  604   opp_3pm_rank                        float32
#  605   opp_3pm_vla                         float32
#  606   opp_3pm_vla_std                     float32
#  607   opp_3pa_rank                        float32
#  608   opp_3pa_vla                         float32
#  609   opp_3pa_vla_std                     float32
#  610   opp_3pt_pct_rank                    float32
#  611   opp_3pt_pct_vla                     float32
#  612   opp_3pt_pct_vla_std                 float32
#  613   opp_ftm_rank                        float32
#  614   opp_ftm_vla                         float32
#  615   opp_ftm_vla_std                     float32
#  616   opp_fta_rank                        float32
#  617   opp_fta_vla                         float32
#  618   opp_fta_vla_std                     float32
#  619   opp_ft_pct_rank                     float32
#  620   opp_ft_pct_vla                      float32
#  621   opp_ft_pct_vla_std                  float32
#  622   opp_oreb_rank                       float32
#  623   opp_oreb_vla                        float32
#  624   opp_oreb_vla_std                    float32
#  625   opp_dreb_rank                       float32
#  626   opp_dreb_vla                        float32
#  627   opp_dreb_vla_std                    float32
#  628   opp_reb_rank                        float32
#  629   opp_reb_vla                         float32
#  630   opp_reb_vla_std                     float32
#  631   opp_ast_rank                        float32
#  632   opp_ast_vla                         float32
#  633   opp_ast_vla_std                     float32
#  634   opp_tov_rank                        float32
#  635   opp_tov_vla                         float32
#  636   opp_tov_vla_std                     float32
#  637   opp_stl_rank                        float32
#  638   opp_stl_vla                         float32
#  639   opp_stl_vla_std                     float32
#  640   opp_blk_rank                        float32
#  641   opp_blk_vla                         float32
#  642   opp_blk_vla_std                     float32
#  643   opp_blka_rank                       float32
#  644   opp_blka_vla                        float32
#  645   opp_blka_vla_std                    float32
#  646   opp_pf_rank                         float32
#  647   opp_pf_vla                          float32
#  648   opp_pf_vla_std                      float32
#  649   opp_pfd_rank                        float32
#  650   opp_pfd_vla                         float32
#  651   opp_pfd_vla_std                     float32
#  652   opp_pts_rank                        float32
#  653   opp_pts_vla                         float32
#  654   opp_pts_vla_std                     float32
#  655   opp_pm_rank                         float32
#  656   opp_pm_vla                          float32
#  657   opp_pm_vla_std                      float32
#  658   opp_fgm_opp                         float32
#  659   opp_fga_opp                         float32
#  660   opp_fg_pct_opp                      float32
#  661   opp_3pm_opp                         float32
#  662   opp_3pa_opp                         float32
#  663   opp_3pt_pct_opp                     float32
#  664   opp_ftm_opp                         float32
#  665   opp_fta_opp                         float32
#  666   opp_ft_pct_opp                      float32
#  667   opp_oreb_opp                        float32
#  668   opp_dreb_opp                        float32
#  669   opp_reb_opp                         float32
#  670   opp_ast_opp                         float32
#  671   opp_tov_opp                         float32
#  672   opp_stl_opp                         float32
#  673   opp_blk_opp                         float32
#  674   opp_blka_opp                        float32
#  675   opp_pf_opp                          float32
#  676   opp_pfd_opp                         float32
#  677   opp_pts_opp                         float32
#  678   opp_pm_opp                          float32
#  679   opp_fgm_rank_opp                    float32
#  680   opp_fgm_vla_opp                     float32
#  681   opp_fgm_vla_std_opp                 float32
#  682   opp_fga_rank_opp                    float32
#  683   opp_fga_vla_opp                     float32
#  684   opp_fga_vla_std_opp                 float32
#  685   opp_fg_pct_rank_opp                 float32
#  686   opp_fg_pct_vla_opp                  float32
#  687   opp_fg_pct_vla_std_opp              float32
#  688   opp_3pm_rank_opp                    float32
#  689   opp_3pm_vla_opp                     float32
#  690   opp_3pm_vla_std_opp                 float32
#  691   opp_3pa_rank_opp                    float32
#  692   opp_3pa_vla_opp                     float32
#  693   opp_3pa_vla_std_opp                 float32
#  694   opp_3pt_pct_rank_opp                float32
#  695   opp_3pt_pct_vla_opp                 float32
#  696   opp_3pt_pct_vla_std_opp             float32
#  697   opp_ftm_rank_opp                    float32
#  698   opp_ftm_vla_opp                     float32
#  699   opp_ftm_vla_std_opp                 float32
#  700   opp_fta_rank_opp                    float32
#  701   opp_fta_vla_opp                     float32
#  702   opp_fta_vla_std_opp                 float32
#  703   opp_ft_pct_rank_opp                 float32
#  704   opp_ft_pct_vla_opp                  float32
#  705   opp_ft_pct_vla_std_opp              float32
#  706   opp_oreb_rank_opp                   float32
#  707   opp_oreb_vla_opp                    float32
#  708   opp_oreb_vla_std_opp                float32
#  709   opp_dreb_rank_opp                   float32
#  710   opp_dreb_vla_opp                    float32
#  711   opp_dreb_vla_std_opp                float32
#  712   opp_reb_rank_opp                    float32
#  713   opp_reb_vla_opp                     float32
#  714   opp_reb_vla_std_opp                 float32
#  715   opp_ast_rank_opp                    float32
#  716   opp_ast_vla_opp                     float32
#  717   opp_ast_vla_std_opp                 float32
#  718   opp_tov_rank_opp                    float32
#  719   opp_tov_vla_opp                     float32
#  720   opp_tov_vla_std_opp                 float32
#  721   opp_stl_rank_opp                    float32
#  722   opp_stl_vla_opp                     float32
#  723   opp_stl_vla_std_opp                 float32
#  724   opp_blk_rank_opp                    float32
#  725   opp_blk_vla_opp                     float32
#  726   opp_blk_vla_std_opp                 float32
#  727   opp_blka_rank_opp                   float32
#  728   opp_blka_vla_opp                    float32
#  729   opp_blka_vla_std_opp                float32
#  730   opp_pf_rank_opp                     float32
#  731   opp_pf_vla_opp                      float32
#  732   opp_pf_vla_std_opp                  float32
#  733   opp_pfd_rank_opp                    float32
#  734   opp_pfd_vla_opp                     float32
#  735   opp_pfd_vla_std_opp                 float32
#  736   opp_pts_rank_opp                    float32
#  737   opp_pts_vla_opp                     float32
#  738   opp_pts_vla_std_opp                 float32
#  739   opp_pm_rank_opp                     float32
#  740   opp_pm_vla_opp                      float32
#  741   opp_pm_vla_std_opp                  float32
#  742   dist_feet                           float32
#  743   dist_miles                          float32
#  744   dist_miles_off                      float32
#  745   dist_miles_def                      float32
#  746   avg_speed                           float32
#  747   avg_speed_off                       float32
#  748   avg_speed_def                       float32
#  749   dist_feet_rank                      float32
#  750   dist_feet_vla                       float32
#  751   dist_feet_vla_std                   float32
#  752   dist_miles_rank                     float32
#  753   dist_miles_vla                      float32
#  754   dist_miles_vla_std                  float32
#  755   dist_miles_off_rank                 float32
#  756   dist_miles_off_vla                  float32
#  757   dist_miles_off_vla_std              float32
#  758   dist_miles_def_rank                 float32
#  759   dist_miles_def_vla                  float32
#  760   dist_miles_def_vla_std              float32
#  761   avg_speed_rank                      float32
#  762   avg_speed_vla                       float32
#  763   avg_speed_vla_std                   float32
#  764   avg_speed_off_rank                  float32
#  765   avg_speed_off_vla                   float32
#  766   avg_speed_off_vla_std               float32
#  767   avg_speed_def_rank                  float32
#  768   avg_speed_def_vla                   float32
#  769   avg_speed_def_vla_std               float32
#  770   dist_feet_opp                       float32
#  771   dist_miles_opp                      float32
#  772   dist_miles_off_opp                  float32
#  773   dist_miles_def_opp                  float32
#  774   avg_speed_opp                       float32
#  775   avg_speed_off_opp                   float32
#  776   avg_speed_def_opp                   float32
#  777   dist_feet_rank_opp                  float32
#  778   dist_feet_vla_opp                   float32
#  779   dist_feet_vla_std_opp               float32
#  780   dist_miles_rank_opp                 float32
#  781   dist_miles_vla_opp                  float32
#  782   dist_miles_vla_std_opp              float32
#  783   dist_miles_off_rank_opp             float32
#  784   dist_miles_off_vla_opp              float32
#  785   dist_miles_off_vla_std_opp          float32
#  786   dist_miles_def_rank_opp             float32
#  787   dist_miles_def_vla_opp              float32
#  788   dist_miles_def_vla_std_opp          float32
#  789   avg_speed_rank_opp                  float32
#  790   avg_speed_vla_opp                   float32
#  791   avg_speed_vla_std_opp               float32
#  792   avg_speed_off_rank_opp              float32
#  793   avg_speed_off_vla_opp               float32
#  794   avg_speed_off_vla_std_opp           float32
#  795   avg_speed_def_rank_opp              float32
#  796   avg_speed_def_vla_opp               float32
#  797   avg_speed_def_vla_std_opp           float32
#  798   fgm_ra                              float32
#  799   fga_ra                              float32
#  800   fg_pct_ra                           float32
#  801   fgm_paint                           float32
#  802   fga_paint                           float32
#  803   fg_pct_paint                        float32
#  804   fgm_mr                              float32
#  805   fga_mr                              float32
#  806   fg_pct_mr                           float32
#  807   fgm_lc3                             float32
#  808   fga_lc3                             float32
#  809   fg_pct_lc3                          float32
#  810   fgm_rc3                             float32
#  811   fga_rc3                             float32
#  812   fg_pct_rc3                          float32
#  813   fgm_c3                              float32
#  814   fga_c3                              float32
#  815   fg_pct_c3                           float32
#  816   fgm_atb3                            float32
#  817   fga_atb3                            float32
#  818   fg_pct_atb3                         float32
#  819   fgm_ra_rank                         float32
#  820   fgm_ra_vla                          float32
#  821   fgm_ra_vla_std                      float32
#  822   fga_ra_rank                         float32
# ...
#  956   fg_pct_c3_vla_std_opp               float32
#  957   fgm_atb3_rank_opp                   float32
#  958   fgm_atb3_vla_opp                    float32
#  959   fgm_atb3_vla_std_opp                float32
#  960   fga_atb3_rank_opp                   float32
#  961   fga_atb3_vla_opp                    float32
#  962   fga_atb3_vla_std_opp                float32
#  963   fg_pct_atb3_rank_opp                float32
#  964   fg_pct_atb3_vla_opp                 float32
#  965   fg_pct_atb3_vla_std_opp             float32
#  966   opp_fgm_ra                          float32
#  967   opp_fga_ra                          float32
#  968   opp_fg_pct_ra                       float32
#  969   opp_fgm_paint                       float32
#  970   opp_fga_paint                       float32
#  971   opp_fg_pct_paint                    float32
#  972   opp_fgm_mr                          float32
#  973   opp_fga_mr                          float32
#  974   opp_fg_pct_mr                       float32
#  975   opp_fgm_lc3                         float32
#  976   opp_fga_lc3                         float32
#  977   opp_fg_pct_lc3                      float32
#  978   opp_fgm_rc3                         float32
#  979   opp_fga_rc3                         float32
#  980   opp_fg_pct_rc3                      float32
#  981   opp_fgm_c3                          float32
#  982   opp_fga_c3                          float32
#  983   opp_fg_pct_c3                       float32
#  984   opp_fgm_atb3                        float32
#  985   opp_fga_atb3                        float32
#  986   opp_fg_pct_atb3                     float32
#  987   opp_fgm_ra_rank                     float32
#  988   opp_fgm_ra_vla                      float32
#  989   opp_fgm_ra_vla_std                  float32
#  990   opp_fga_ra_rank                     float32
#  991   opp_fga_ra_vla                      float32
#  992   opp_fga_ra_vla_std                  float32
#  993   opp_fg_pct_ra_rank                  float32
#  994   opp_fg_pct_ra_vla                   float32
#  995   opp_fg_pct_ra_vla_std               float32
#  996   opp_fgm_paint_rank                  float32
#  997   opp_fgm_paint_vla                   float32
#  998   opp_fgm_paint_vla_std               float32
#  999   opp_fga_paint_rank                  float32
#  1000  opp_fga_paint_vla                   float32
#  1001  opp_fga_paint_vla_std               float32
#  1002  opp_fg_pct_paint_rank               float32
#  1003  opp_fg_pct_paint_vla                float32
#  1004  opp_fg_pct_paint_vla_std            float32
#  1005  opp_fgm_mr_rank                     float32
#  1006  opp_fgm_mr_vla                      float32
#  1007  opp_fgm_mr_vla_std                  float32
#  1008  opp_fga_mr_rank                     float32
#  1009  opp_fga_mr_vla                      float32
#  1010  opp_fga_mr_vla_std                  float32
#  1011  opp_fg_pct_mr_rank                  float32
#  1012  opp_fg_pct_mr_vla                   float32
#  1013  opp_fg_pct_mr_vla_std               float32
#  1014  opp_fgm_lc3_rank                    float32
#  1015  opp_fgm_lc3_vla                     float32
#  1016  opp_fgm_lc3_vla_std                 float32
#  1017  opp_fga_lc3_rank                    float32
#  1018  opp_fga_lc3_vla                     float32
#  1019  opp_fga_lc3_vla_std                 float32
#  1020  opp_fg_pct_lc3_rank                 float32
#  1021  opp_fg_pct_lc3_vla                  float32
#  1022  opp_fg_pct_lc3_vla_std              float32
#  1023  opp_fgm_rc3_rank                    float32
#  1024  opp_fgm_rc3_vla                     float32
#  1025  opp_fgm_rc3_vla_std                 float32
#  1026  opp_fga_rc3_rank                    float32
#  1027  opp_fga_rc3_vla                     float32
#  1028  opp_fga_rc3_vla_std                 float32
#  1029  opp_fg_pct_rc3_rank                 float32
#  1030  opp_fg_pct_rc3_vla                  float32
#  1031  opp_fg_pct_rc3_vla_std              float32
#  1032  opp_fgm_c3_rank                     float32
#  1033  opp_fgm_c3_vla                      float32
#  1034  opp_fgm_c3_vla_std                  float32
#  1035  opp_fga_c3_rank                     float32
#  1036  opp_fga_c3_vla                      float32
#  1037  opp_fga_c3_vla_std                  float32
#  1038  opp_fg_pct_c3_rank                  float32
#  1039  opp_fg_pct_c3_vla                   float32
#  1040  opp_fg_pct_c3_vla_std               float32
#  1041  opp_fgm_atb3_rank                   float32
#  1042  opp_fgm_atb3_vla                    float32
#  1043  opp_fgm_atb3_vla_std                float32
#  1044  opp_fga_atb3_rank                   float32
#  1045  opp_fga_atb3_vla                    float32
#  1046  opp_fga_atb3_vla_std                float32
#  1047  opp_fg_pct_atb3_rank                float32
#  1048  opp_fg_pct_atb3_vla                 float32
#  1049  opp_fg_pct_atb3_vla_std             float32
#  1050  opp_fgm_ra_opp                      float32
#  1051  opp_fga_ra_opp                      float32
#  1052  opp_fg_pct_ra_opp                   float32
#  1053  opp_fgm_paint_opp                   float32
#  1054  opp_fga_paint_opp                   float32
#  1055  opp_fg_pct_paint_opp                float32
#  1056  opp_fgm_mr_opp                      float32
#  1057  opp_fga_mr_opp                      float32
#  1058  opp_fg_pct_mr_opp                   float32
#  1059  opp_fgm_lc3_opp                     float32
#  1060  opp_fga_lc3_opp                     float32
#  1061  opp_fg_pct_lc3_opp                  float32
#  1062  opp_fgm_rc3_opp                     float32
#  1063  opp_fga_rc3_opp                     float32
#  1064  opp_fg_pct_rc3_opp                  float32
#  1065  opp_fgm_c3_opp                      float32
#  1066  opp_fga_c3_opp                      float32
#  1067  opp_fg_pct_c3_opp                   float32
#  1068  opp_fgm_atb3_opp                    float32
#  1069  opp_fga_atb3_opp                    float32
#  1070  opp_fg_pct_atb3_opp                 float32
#  1071  opp_fgm_ra_rank_opp                 float32
#  1072  opp_fgm_ra_vla_opp                  float32
#  1073  opp_fgm_ra_vla_std_opp              float32
#  1074  opp_fga_ra_rank_opp                 float32
#  1075  opp_fga_ra_vla_opp                  float32
#  1076  opp_fga_ra_vla_std_opp              float32
#  1077  opp_fg_pct_ra_rank_opp              float32
#  1078  opp_fg_pct_ra_vla_opp               float32
#  1079  opp_fg_pct_ra_vla_std_opp           float32
#  1080  opp_fgm_paint_rank_opp              float32
#  1081  opp_fgm_paint_vla_opp               float32
#  1082  opp_fgm_paint_vla_std_opp           float32
#  1083  opp_fga_paint_rank_opp              float32
#  1084  opp_fga_paint_vla_opp               float32
#  1085  opp_fga_paint_vla_std_opp           float32
#  1086  opp_fg_pct_paint_rank_opp           float32
#  1087  opp_fg_pct_paint_vla_opp            float32
#  1088  opp_fg_pct_paint_vla_std_opp        float32
#  1089  opp_fgm_mr_rank_opp                 float32
#  1090  opp_fgm_mr_vla_opp                  float32
#  1091  opp_fgm_mr_vla_std_opp              float32
#  1092  opp_fga_mr_rank_opp                 float32
#  1093  opp_fga_mr_vla_opp                  float32
#  1094  opp_fga_mr_vla_std_opp              float32
#  1095  opp_fg_pct_mr_rank_opp              float32
#  1096  opp_fg_pct_mr_vla_opp               float32
#  1097  opp_fg_pct_mr_vla_std_opp           float32
#  1098  opp_fgm_lc3_rank_opp                float32
#  1099  opp_fgm_lc3_vla_opp                 float32
#  1100  opp_fgm_lc3_vla_std_opp             float32
#  1101  opp_fga_lc3_rank_opp                float32
#  1102  opp_fga_lc3_vla_opp                 float32
#  1103  opp_fga_lc3_vla_std_opp             float32
#  1104  opp_fg_pct_lc3_rank_opp             float32
#  1105  opp_fg_pct_lc3_vla_opp              float32
#  1106  opp_fg_pct_lc3_vla_std_opp          float32
#  1107  opp_fgm_rc3_rank_opp                float32
#  1108  opp_fgm_rc3_vla_opp                 float32
#  1109  opp_fgm_rc3_vla_std_opp             float32
#  1110  opp_fga_rc3_rank_opp                float32
#  1111  opp_fga_rc3_vla_opp                 float32
#  1112  opp_fga_rc3_vla_std_opp             float32
#  1113  opp_fg_pct_rc3_rank_opp             float32
#  1114  opp_fg_pct_rc3_vla_opp              float32
#  1115  opp_fg_pct_rc3_vla_std_opp          float32
#  1116  opp_fgm_c3_rank_opp                 float32
#  1117  opp_fgm_c3_vla_opp                  float32
#  1118  opp_fgm_c3_vla_std_opp              float32
#  1119  opp_fga_c3_rank_opp                 float32
#  1120  opp_fga_c3_vla_opp                  float32
#  1121  opp_fga_c3_vla_std_opp              float32
#  1122  opp_fg_pct_c3_rank_opp              float32
#  1123  opp_fg_pct_c3_vla_opp               float32
#  1124  opp_fg_pct_c3_vla_std_opp           float32
#  1125  opp_fgm_atb3_rank_opp               float32
#  1126  opp_fgm_atb3_vla_opp                float32
#  1127  opp_fgm_atb3_vla_std_opp            float32
#  1128  opp_fga_atb3_rank_opp               float32
#  1129  opp_fga_atb3_vla_opp                float32
#  1130  opp_fga_atb3_vla_std_opp            float32
#  1131  opp_fg_pct_atb3_rank_opp            float32
#  1132  opp_fg_pct_atb3_vla_opp             float32
#  1133  opp_fg_pct_atb3_vla_std_opp         float32
#  1134  screen_ast                          float32
#  1135  screen_ast_pts                      float32
#  1136  deflections                         float32
#  1137  off_loose_ball_rec                  float32
#  1138  def_loose_ball_rec                  float32
#  1139  loose_ball_rec                      float32
#  1140  pct_loose_ball_rec_off              float32
#  1141  pct_loose_ball_rec_def              float32
#  1142  charges_drawn                       float32
#  1143  contested_2pt                       float32
#  1144  contested_3pt                       float32
#  1145  contested_shots                     float32
#  1146  screen_ast_rank                     float32
#  1147  screen_ast_vla                      float32
#  1148  screen_ast_vla_std                  float32
#  1149  screen_ast_pts_rank                 float32
#  1150  screen_ast_pts_vla                  float32
#  1151  screen_ast_pts_vla_std              float32
#  1152  deflections_rank                    float32
#  1153  deflections_vla                     float32
#  1154  deflections_vla_std                 float32
#  1155  off_loose_ball_rec_rank             float32
#  1156  off_loose_ball_rec_vla              float32
#  1157  off_loose_ball_rec_vla_std          float32
#  1158  def_loose_ball_rec_rank             float32
#  1159  def_loose_ball_rec_vla              float32
#  1160  def_loose_ball_rec_vla_std          float32
#  1161  loose_ball_rec_rank                 float32
#  1162  loose_ball_rec_vla                  float32
#  1163  loose_ball_rec_vla_std              float32
#  1164  pct_loose_ball_rec_off_rank         float32
#  1165  pct_loose_ball_rec_off_vla          float32
#  1166  pct_loose_ball_rec_off_vla_std      float32
#  1167  pct_loose_ball_rec_def_rank         float32
#  1168  pct_loose_ball_rec_def_vla          float32
#  1169  pct_loose_ball_rec_def_vla_std      float32
#  1170  charges_drawn_rank                  float32
#  1171  charges_drawn_vla                   float32
#  1172  charges_drawn_vla_std               float32
#  1173  contested_2pt_rank                  float32
#  1174  contested_2pt_vla                   float32
#  1175  contested_2pt_vla_std               float32
#  1176  contested_3pt_rank                  float32
#  1177  contested_3pt_vla                   float32
#  1178  contested_3pt_vla_std               float32
#  1179  contested_shots_rank                float32
#  1180  contested_shots_vla                 float32
#  1181  contested_shots_vla_std             float32
#  1182  screen_ast_opp                      float32
#  1183  screen_ast_pts_opp                  float32
#  1184  deflections_opp                     float32
#  1185  off_loose_ball_rec_opp              float32
#  1186  def_loose_ball_rec_opp              float32
#  1187  loose_ball_rec_opp                  float32
#  1188  pct_loose_ball_rec_off_opp          float32
#  1189  pct_loose_ball_rec_def_opp          float32
#  1190  charges_drawn_opp                   float32
#  1191  contested_2pt_opp                   float32
#  1192  contested_3pt_opp                   float32
#  1193  contested_shots_opp                 float32
#  1194  screen_ast_rank_opp                 float32
#  1195  screen_ast_vla_opp                  float32
#  1196  screen_ast_vla_std_opp              float32
#  1197  screen_ast_pts_rank_opp             float32
#  1198  screen_ast_pts_vla_opp              float32
#  1199  screen_ast_pts_vla_std_opp          float32
#  1200  deflections_rank_opp                float32
#  1201  deflections_vla_opp                 float32
#  1202  deflections_vla_std_opp             float32
#  1203  off_loose_ball_rec_rank_opp         float32
#  1204  off_loose_ball_rec_vla_opp          float32
#  1205  off_loose_ball_rec_vla_std_opp      float32
#  1206  def_loose_ball_rec_rank_opp         float32
#  1207  def_loose_ball_rec_vla_opp          float32
#  1208  def_loose_ball_rec_vla_std_opp      float32
#  1209  loose_ball_rec_rank_opp             float32
#  1210  loose_ball_rec_vla_opp              float32
#  1211  loose_ball_rec_vla_std_opp          float32
#  1212  pct_loose_ball_rec_off_rank_opp     float32
#  1213  pct_loose_ball_rec_off_vla_opp      float32
#  1214  pct_loose_ball_rec_off_vla_std_opp  float32
#  1215  pct_loose_ball_rec_def_rank_opp     float32
#  1216  pct_loose_ball_rec_def_vla_opp      float32
#  1217  pct_loose_ball_rec_def_vla_std_opp  float32
#  1218  charges_drawn_rank_opp              float32
#  1219  charges_drawn_vla_opp               float32
#  1220  charges_drawn_vla_std_opp           float32
#  1221  contested_2pt_rank_opp              float32
#  1222  contested_2pt_vla_opp               float32
#  1223  contested_2pt_vla_std_opp           float32
#  1224  contested_3pt_rank_opp              float32
#  1225  contested_3pt_vla_opp               float32
#  1226  contested_3pt_vla_std_opp           float32
#  1227  contested_shots_rank_opp            float32
#  1228  contested_shots_vla_opp             float32
#  1229  contested_shots_vla_std_opp         float32
# dtypes: datetime64[ns](2), float32(1221), object(7)
# memory usage: 43.6+ MB

# %% [markdown]
# # Save to RDS

# %%
# full_dataset.to_sql(name='combined_nba_covers', con=connection, index=False, if_exists='replace')
